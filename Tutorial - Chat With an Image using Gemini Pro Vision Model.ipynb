# %% [markdown]
# # Chat with an Image using Gemini Pro Vision Model

# %% [markdown]
# ### Installing required libraries

# %%
pip install -q pillow
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -q google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import Libraries

# %%
import os
import google.generativeai as genai
from dotenv import load_dotenv, find_dotenv

# %% [markdown]
# ### Load Environment variable

# %%
load_dotenv(find_dotenv(), override=True)
genai.configure(api_key=os.environ.get('GOOGLE_API_KEY'))

# %%
from PIL import Image
image_path = input('Please enter your image path:')
if not os.path.isfile(image_path):
    raise SystemExit('Incorrect image! quitting...')
img = Image.open(image_path)
img
# Out:
# Please enter your image path:./Files/fridge.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1178x1460>

# %%
model = genai.GenerativeModel('gemini-pro-vision')
while True:
    prompt = input('Ask somthing about your image ...')
    if prompt.lower() not in ['exit','quit']:
        response = model.generate_content([prompt, img])
        print('')
        print(response.text)
        print('-' * 100)
    else:
        print('Exiting ...')
        break
# Out:
# Ask somthing about your image ...Please list the items in the fridge
#
#  The fridge contains the following items:
#
# * A bottle of wine
# * A box of baking soda
# * A jar of pickles
# * A jar of olives
# * A jar of kimchi
# * A jar of sauerkraut
# * A jar of salsa
# * A jar of hummus
# * A container of tofu
# * A container of yogurt
# * A container of cottage cheese
# * A container of sour cream
# * A container of milk
# * A container of eggs
# * A container of fruit
# * A container of vegetables
# * A container of meat
# * A container of cheese
# * A container of leftovers
# * A container of ice cream
# * A container of popsicles
# * A container of frozen yogurt
# * A container of frozen fruit
# * A container of frozen vegetables
# * A container of frozen meat
# * A container of frozen fish
# * A container of frozen pizza
# * A container of frozen waffles
# * A container of frozen pancakes
# * A container of frozen french fries
# * A container of frozen tater tots
# ...
