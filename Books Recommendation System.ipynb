# %% [markdown]
# # Books Recommendation System

# %% [markdown]
# ### Install Required Libraries

# %%
# !pip install -q openai
# !pip install -q pandas
# !pip install -q numpy

# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /opt/anaconda3/lib/python3.11/site-packages (1.23.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.10.12)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.8.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)

# %% [markdown]
# ### Import Libraries

# %%
import openai
import pandas as pd
import numpy as np

# %%
from openai import OpenAI
client = OpenAI()

# %% [markdown]
# ### Load Environment Variables

# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)

os.environ.get('OPENAI_API_KEY')

print("API Key Loaded:", os.environ.get('OPENAI_API_KEY') is not None)
# Out:
# API Key Loaded: True

# %% [markdown]
# ### Load Dataset into Pandas DataFrame

# %%
df = pd.read_csv('./data.csv')
df.dropna(inplace=True)
df = df.sort_values('average_rating', ascending=False).head(2000)
df
# df.iloc[1581]
# Out:
#              isbn13      isbn10                         title  \
# 4306  9780739844328  0739844326                    Bill Gates
# 5972  9781551052700  1551052709          Ecuador Nature Guide
# 6720  9781930901353  1930901356           The Irish Anatomist
# 6738  9781932206081  1932206086                      Insights
# 6671  9781890995522  1890995525  The Diamond Color Meditation
# ...             ...         ...                           ...
# 974   9780142003299  0142003298                     Octopussy
# 6197  9781578068012  1578068010                   Daisy Bates
# 3645  9780586203194  0586203192                          2061
# 5792  9781401200688  1401200680      On the Road to Perdition
# 1054  9780143038412  0143038419               Eat, Pray, Love
#
#                                                subtitle  \
# 4306                                    Computer Legend
# 5972       Southwest Forests : Sozoranga Forest Project
# 6720                           A Study of Flann O'Brien
# 6738                   Talks on the Nature of Existence
# 6671                          Color Pathway to the Soul
# ...                                                 ...
# 974                            And the Living Daylights
# 6197                Civil Rights Crusader from Arkansas
# 3645                                      Odyssey Three
# 5792                                              Oasis
# 1054  One Woman's Search for Everything Across Italy...
#
#                                        authors                 categories  \
# 4306                          Sara Barton-Wood        Juvenile Nonfiction
# 5972                    Christopher D. Jiggins                  Botanique
# 6720                             Keith Donohue  Biography & Autobiography
# 6738                            Frederick Lenz             Spiritual life
# 6671                              John Diamond           Health & Fitness
# ...                                        ...                        ...
# 974                                Ian Fleming                    Fiction
# 6197                             Grif Stockley  Biography & Autobiography
# 3645                          Arthur C. Clarke                  Computers
# 5792  Max Allan Collins;Jose Luis Garcia-Lopez    Comics & Graphic Novels
# 1054                         Elizabeth Gilbert  Biography & Autobiography
#
#                                               thumbnail  \
# 4306  http://books.google.com/books/content?id=Fr814...
# 5972  http://books.google.com/books/content?id=1JjbG...
# 6720  http://books.google.com/books/content?id=baEJA...
# 6738  http://books.google.com/books/content?id=NOX2P...
# 6671  http://books.google.com/books/content?id=1ChsH...
# ...                                                 ...
# 974   http://books.google.com/books/content?id=B5vGA...
# 6197  http://books.google.com/books/content?id=rsd_m...
# 3645  http://books.google.com/books/content?id=uSj0D...
# 5792  http://books.google.com/books/content?id=VqrUX...
# 1054  http://books.google.com/books/content?id=zquLD...
#
#                                             description  published_year  \
# 4306  Presents the life of Bill Gates, from his chil...          2001.0
# 5972  The guide provides information on 76 species o...          2000.0
# 6720  The most full length critical and biographical...          2002.0
# 6738  In 1983, when Rama - Dr. Frederick P. Lenz rec...          2003.0
# 6671  The Diamond Color Meditation presents an inspi...          2006.0
# ...                                                 ...             ...
# 974   The legendary 007 deals with a rich, deranged ...          2004.0
# 6197  Daisy Bates (1914-1999) is renowned as the men...          2005.0
# 3645                             Science fiction-roman.          1997.0
# 5792  Renegade mob hitman Michael O'Sullivan--the "A...          2003.0
# 1054                              GILBERT/EAT PRAY LOVE          2007.0
#
#       average_rating  num_pages  ratings_count
# 4306            5.00       48.0            0.0
# 5972            5.00       96.0            1.0
# 6720            5.00      222.0            1.0
# 6738            5.00      304.0            1.0
# 6671            5.00       74.0            5.0
# ...              ...        ...            ...
# 974             3.55      120.0         4801.0
# 6197            3.55      340.0           11.0
# 3645            3.55      302.0        20216.0
# 5792            3.54       96.0           74.0
# 1054            3.54      368.0      1309623.0
#
# [2000 rows x 12 columns]

# %% [markdown]
# ### Embedding Cost Calculation

# %%
import tiktoken
enc = tiktoken.encoding_for_model('text-embedding-3-small')
descriptions = list(df['description'])
total_tokens = sum([len(enc.encode(item)) for item in descriptions])
print(f'Total tokens: {total_tokens}')
cost = total_tokens * (0.0004/1000)
print(f'Estimated cost in USD: {cost:.10f}')
# Out:
# Total tokens: 188119
# Estimated cost in USD: 0.0752476000

# %% [markdown]
# ### Calculate the embeddings and cache them locally

# %%
def get_embedding(text, model="text-embedding-3-small"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
def get_embeddings_and_save_to_csv(embedding_cache_file):
    df['embedding']=df['description'].apply(lambda x: get_embedding(x, model='text-embedding-3-small'))
    df.to_csv(embedding_cache_file)

# %%
embedding_cache_file = 'book_embeddings.csv'
get_embeddings_and_save_to_csv(embedding_cache_file)

# %%
# an example of how the embeddings look without visualization
print(list(df_embeddings['embedding'].iloc[0]))
# Out:
# [0.05363256856799126, -0.018259329721331596, 0.01940474845468998, 0.06297559291124344, -0.009028598666191101, -0.08247017860412598, 0.04923056438565254, 0.06293068081140518, -0.0005979762063361704, 0.03085894137620926, 0.02757989801466465, 0.028141377493739128, 0.012172886170446873, -0.05053320154547691, 0.04521036893129349, 0.048107605427503586, -0.05188075080513954, 0.005471622571349144, -0.012958958745002747, 0.011358740739524364, 0.016653496772050858, 0.028298592194914818, 0.017978589981794357, 0.021257633343338966, -0.006198739167302847, -0.002664222614839673, 0.042650021612644196, 0.03270059451460838, 0.014912908896803856, 0.010134713724255562, -0.02107795886695385, -0.002502797171473503, 0.05206042528152466, 0.02032557502388954, 0.03827047720551491, -0.004463765770196915, -0.01889941655099392, -0.010241394862532616, 0.007304854691028595, 0.011179067194461823, -0.02735530585050583
#
#                                               embedding
# 0     [0.05363256856799126, -0.018259329721331596, 0...
# 1     [0.060896094888448715, -0.010619226843118668, ...
# 2     [0.03172249346971512, 0.03664880990982056, -0....
# 3     [-0.011502875946462154, -0.009286032989621162,...
# 4     [0.004097896162420511, 0.004661967046558857, 0...
# ...                                                 ...
# 1995  [-0.027058351784944534, 0.019854001700878143, ...
# 1996  [0.07347182929515839, -0.028972012922167778, 0...
# 1997  [-0.03379650041460991, 0.0369640588760376, -0....
# 1998  [0.029538720846176147, 0.05673157796263695, -0...
# 1999  [-0.05307612195611, 0.008566507138311863, -0.0...
#
# [2000 rows x 14 columns]

# %% [markdown]
# ### Get Recommendation from Book title

# %%
def get_recommendation_from_title(df_embeddings, title, k):
    from scipy.spatial.distance import cosine

    if title not in list(df_embeddings['title']):
        return False

    book_embedding = df_embeddings[df_embeddings['title'] == title]['embedding'].iloc[0]
    book_embedding = book_embedding.squeeze()

    embeddings = list(df_embeddings['embedding'])

    distances = [cosine(book_embedding, emb) for emb in embeddings]

    #print(sorted(distances))
    closest_indices = np.argsort(distances)[:k]  
    # print(closest_indices)
    recommendations = list()
    for index in closest_indices[1:k+1]:
        book = dict()
        book['title']=df_embeddings.iloc[index]['title']
        book['description'] = df_embeddings.iloc[index]['description']
        book['distance']=distances[index]
        recommendations.append(book)

    return recommendations

# %%
get_recommendation_from_title(df_embeddings, 'The Irish Anatomist', 10)
# Out:
# [{'title': 'The Gatekeeper',
#   'description': 'An Oxford scholar and author of The Truth About the Irish candidly recounts his experiences as an impoverished youth, a convent gatekeeper, a Catholic in Protestant England, a working-class Irish immigrant among the Oxbridge elite, and a Marxist visiting professor in Mormon Utah. Reprint. 15,000 first printing.',
#   'distance': 0.5517319540653511},
#  {'title': 'The Family Idiot',
#   'description': 'With this volume, the University of Chicago Press completes its translation of a work that is indispensable not only to serious readers of Flaubert but to anyone interested in the last major contribution by one of the twentieth century\'s greatest thinkers. That Sartre\'s study of Flaubert, The Family Idiot, is a towering achievement in intellectual history has never been disputed. Yet critics have argued about the precise nature of this novel or biography or "criticism-fiction" which is the summation of Sartre\'s philosophical, social, and literary thought. In the preface, Sartre writes: "The Family Idiot is the sequel to Search for a Method. The subject: what, at this point in time, can we know about a man? It seemed to me that this question could only be answered by studying a specific case." Sartre discusses Flaubert\'s personal development, his relationship to his family, his decision to become a writer, and the psychosomatic crisis or "conversion" from his father\'s domination to the freedom of his art. Sartre blends psychoanalysis with a sociological study of the ideology of the period, the crisis in literature, and Flaubert\'s influence on the future of literature. While Sartre never wrote the final volume he envisioned for this vast project, the existing volumes constitute in themselves a unified work—one that John Sturrock, writing in the Observer, called "a shatteringly fertile, digressive and ruthless interpretation of these few cardinal years in Flaubert\'s life." "A virtuoso perfomance. . . . For all that this book does to make one reconsider his life, The Family Idiot is less a case study of Flaubert than it is a final installment of Sartre\'s mythology. . . . The translator, Carol Cosman, has acquitted herself brilliantly."—Frederick Brown, New York Review of Books "A splendid translation by Carol Cosman. . . . Sartre called The Family Idiot a \'true novel,\' and it does tell a story and eventually reach a shattering climax. The work can be described most simply as a dialectic, which shifts between two seemingly alternative interpretations of Flaubert\'s destiny: a psychoanalytic one, centered on his family and on his childhood, and a Marxist one, whose guiding themes are the status of the artist in Flaubert\'s period and the historical and ideological contradictions faced by his social class, the bourgeoisie."—Fredric Jameson, New York Times Book Review Jean-Paul Sartre (1906-1980) was offered, but declined, the Nobel Prize for literature in 1964. His many works of fiction, drama, and philosophy include the monumental study of Flaubert, The Family Idiot, and The Freud Scenario, both published in translation by the University of Chicago Press.',
#   'distance': 0.568116330689932},
#  {'title': 'The Sign of the Cross',
#   'description': "An insightful and personal examination of Catholicism in Europe.For four years from 1990, Colm Tóibin made a series of trips through Catholic Europe. The result is this beautifully wrought book. He shows the complications and contradictions of the Catholic Church, and tries to unravel how they in turn influence a country's sense of nationalism. It is not quite a travelogue, nor is it autobiographical. Rather it is a work that tests both faith and the written word, a work that redefines what we have come to expect from non-fiction.",
#   'distance': 0.5833932122255328},
#  {'title': 'Finders Keepers',
#   'description': 'In addition to his well-regarded verse, Nobel laureate poet Seamus Heaney has amassed a body of prose works over the last 30-plus years, previously published chiefly in three separate books. Finders Keepers: Selected Prose 1971-2001, offers a "best of" (of sorts) as Heaney sifts through previous writings and offers a variety of strong works, from memoir to lecture transcripts to literary criticism.',
#   'distance': 0.5864225059103025},
#  {'title': 'My Favourite Year',
#   'description': 'Roddy Doyle¿s account of the Republic of Ireland¿s triumphant journey through Italia ¿90 is just one of the many first-class pieces in this anthology of original football writing. Contributors include: Roddy Doyle, Harry Pearson, Harry Ritchie, Ed Horton, Olly Wicken, D.J. Taylor, Huw Richards, Nick Hornby, Chris Pierson, Matt Nation, Graham Brack, Don Watson and Giles Smith. ¿A new kind of football writing developed ¿ passionate, disrespectful, self-mocking, yet steeped in personal bias. In book form, young writers such as Nick Hornby and Pete Davies became to the New Football Writing what Tom Wolfe and Hunter S. Thompson had been to the New Journalism¿ Terence Blacker, Sunday Times',
#   'distance': 0.5868833039472904},
#  {'title': 'Oblivion',
#   'description': 'In the stories that make up Oblivion, David Foster Wallace joins the rawest, most naked humanity with the infinite involutions of self-consciousness--a combination that is dazzlingly, uniquely his. These are worlds undreamt-of by any other mind. Only David Foster Wallace could convey a father\'s desperate loneliness by way of his son\'s daydreaming through a teacher\'s homicidal breakdown ("The Soul Is Not a Smithy"). Or could explore the deepest and most hilarious aspects of creativity by delineating the office politics surrounding a magazine profile of an artist who produces miniature sculptures in an anatomically inconceivable way ("The Suffering Channel"). Or capture the ache of love\'s breakdown in the painfully polite apologies of a man who believes his wife is hallucinating the sound of his snoring ("Oblivion"). Each of these stories is a complete world, as fully imagined as most entire novels, at once preposterously surreal and painfully immediate.',
#   'distance': 0.588627558072083},
#  {'title': "Banvard's Folly",
#   'description': 'The historical record crowns success. Those enshrined in its annals are men and women whose ideas, accomplishments, or personalities have dominated, endured, and most important of all, found champions. John F. Kennedy\'s Profiles in Courage, Giorgio Vasari\'s Lives of the Artists, and Samuel Johnson\'s Lives of the Poets are classic celebrations of the greatest, the brightest, the eternally constellated. Paul Collins\' Banvard\'s Folly is a different kind of book. Here are thirteen unforgettable portraits of forgotten people: men and women who might have claimed their share of renown but who, whether from ill timing, skullduggery, monomania, the tinge of madness, or plain bad luck-or perhaps some combination of them all-leapt straight from life into thankless obscurity. Among their number are scientists, artists, writers, entrepreneurs, and adventurers, from across the centuries and around the world. They hold in common the silenced aftermath of failure, the name that rings no bells. Collins brings them back to glorious life. John Banvard was an artist whose colossal panoramic canvasses (one behemoth depiction of the entire eastern shore of the Mississippi River was simply known as "The Three Mile Painting") made him the richest and most famous artist of his day. . . before he decided to go head to head with P. T. Barnum. René Blondot was a distinguished French physicist whose celebrated discovery of a new form of radiation, called the N-Ray, went terribly awry. At the tender age of seventeen, William Henry Ireland signed "William Shakespeare" to a book and launched a short but meteoric career as a forger of undiscovered works by the Bard -- until he pushed his luck too far. John Symmes, a hero of the War of 1812, nearly succeeded in convincing Congress to fund an expedition to the North Pole, where he intended to prove his theory that the earth was hollow and ripe for exploitation; his quixotic quest counted Jules Verne and Edgar Allan Poe among its greatest admirers. Collins\' love for what he calls the "forgotten ephemera of genius" give his portraits of these figures and the other nine men and women in Banvard\'s Folly sympathetic depth and poignant relevance. Their effect is not to make us sneer or revel in schadenfreude; here are no cautionary tales. Rather, here are brief introductions-acts of excavation and reclamation-to people whom history may have forgotten, but whom now we cannot.',
#   'distance': 0.5895860894163911},
#  {'title': 'The Curtain',
#   'description': "Traces the author's personal view of the history and significance of the novel in western civilization, arguing that a novel's development crosses international and language boundaries while serving to reveal previously unknown aspects of a reader's existence. By the author of The Art of the Novel. 35,000 first printing.",
#   'distance': 0.5900841606605911},
#  {'title': 'Pleasing Myself',
#   'description': 'Frank Kermode has often said that much of his best work has been done at shorter length, in the essays he has written on a very wide range of subjects for literary journals of one kind or another. This volume brings together a selection of these pieces that have been written since the 1990s, on topics as diverse as Donne, Yeats, Howard Hodgkin, gnosticism, the sea and money, as well as futher thoughts on Shakespeare.',
#   'distance': 0.5925959092244326}]

# %%
title = input('Enter Book\'s Title: ')
book_recommendations = get_recommendation_from_title(df_embeddings, title, 5)
# print(book_recommendations)
if book_recommendations:
    for i, item in enumerate(book_recommendations):
        print(f'Book recommendation #{i+1}, Distance: {item["distance"]}')
        print(f'Title: {item["title"]}')
        print(f'Description: {item["description"]}')
        print()
        print('#' * 50)
        print()
else:
    print(f'Title {title} does not exist in the dataset')
# Out:
# Enter Book's Title:  Bill Gates
# Book recommendation #1, Distance: 0.2091330601137581
# Title: Hard Drive
# Description: Chronicles the career of "Chairman Bill" Gates, the computer whiz kid who commands the powerful Microsoft computer software empire.
#
# ##################################################
#
# Book recommendation #2, Distance: 0.5302106646883478
# Title: Think and Grow Rich
# Description: An updated edition of the best-selling guide features anecdotes about such modern figures as Bill Gates, Dave Thomas, and Sir John Templeton, explaining how their examples can enable modern readers to pursue wealth and overcome personal stumbling blocks. Original. 30,000 first printing.
#
# ##################################################
#
# Book recommendation #3, Distance: 0.5524400806751422
# Title: IWoz
# Description: The high-tech wizard behind Apple offers a personal account of the creation of the first personal computer by marrying computer circuitry with a video screen and a typewriter keyboard to create the affordable, easy-to-use Apple I, detailing his life before and after Apple and providing a personal perspective on an invention that ignited the computer revolution. 50,000 first printing.
#
# ##################################################
#
# Book recommendation #4, Distance: 0.5656985425192288
# Title: Q
# Description: The legendary musician, producer, and arranger chronicles his rise to the heights of the entertainment world, detailing his painful youth, his musical and business accomplishments, and his turbulent personal life.
#
# ##################################################

# %% [markdown]
# ### Displaying Emeddings on Atlas

# %%
import openai
import pandas as pd
import numpy as np
from nomic import atlas

# %%
embedding_cache_file = './book_embeddings.csv'
df = pd.read_csv(embedding_cache_file)
df
# Out:
#       Unnamed: 0         isbn13      isbn10                         title  \
# 0           4306  9780739844328  0739844326                    Bill Gates
# 1           5972  9781551052700  1551052709          Ecuador Nature Guide
# 2           6720  9781930901353  1930901356           The Irish Anatomist
# 3           6738  9781932206081  1932206086                      Insights
# 4           6671  9781890995522  1890995525  The Diamond Color Meditation
# ...          ...            ...         ...                           ...
# 1995         974  9780142003299  0142003298                     Octopussy
# 1996        6197  9781578068012  1578068010                   Daisy Bates
# 1997        3645  9780586203194  0586203192                          2061
# 1998        5792  9781401200688  1401200680      On the Road to Perdition
# 1999        1054  9780143038412  0143038419               Eat, Pray, Love
#
#                                                subtitle  \
# 0                                       Computer Legend
# 1          Southwest Forests : Sozoranga Forest Project
# 2                              A Study of Flann O'Brien
# 3                      Talks on the Nature of Existence
# 4                             Color Pathway to the Soul
# ...                                                 ...
# 1995                           And the Living Daylights
# 1996                Civil Rights Crusader from Arkansas
# 1997                                      Odyssey Three
# 1998                                              Oasis
# 1999  One Woman's Search for Everything Across Italy...
#
#                                        authors                 categories  \
# 0                             Sara Barton-Wood        Juvenile Nonfiction
# 1                       Christopher D. Jiggins                  Botanique
# 2                                Keith Donohue  Biography & Autobiography
# 3                               Frederick Lenz             Spiritual life
# 4                                 John Diamond           Health & Fitness
# ...                                        ...                        ...
# 1995                               Ian Fleming                    Fiction
# 1996                             Grif Stockley  Biography & Autobiography
# 1997                          Arthur C. Clarke                  Computers
# 1998  Max Allan Collins;Jose Luis Garcia-Lopez    Comics & Graphic Novels
# 1999                         Elizabeth Gilbert  Biography & Autobiography
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=Fr814...
# 1     http://books.google.com/books/content?id=1JjbG...
# 2     http://books.google.com/books/content?id=baEJA...
# 3     http://books.google.com/books/content?id=NOX2P...
# 4     http://books.google.com/books/content?id=1ChsH...
# ...                                                 ...
# 1995  http://books.google.com/books/content?id=B5vGA...
# 1996  http://books.google.com/books/content?id=rsd_m...
# 1997  http://books.google.com/books/content?id=uSj0D...
# 1998  http://books.google.com/books/content?id=VqrUX...
# 1999  http://books.google.com/books/content?id=zquLD...
#
#                                             description  published_year  \
# 0     Presents the life of Bill Gates, from his chil...          2001.0
# 1     The guide provides information on 76 species o...          2000.0
# 2     The most full length critical and biographical...          2002.0
# 3     In 1983, when Rama - Dr. Frederick P. Lenz rec...          2003.0
# 4     The Diamond Color Meditation presents an inspi...          2006.0
# ...                                                 ...             ...
# 1995  The legendary 007 deals with a rich, deranged ...          2004.0
# 1996  Daisy Bates (1914-1999) is renowned as the men...          2005.0
# 1997                             Science fiction-roman.          1997.0
# 1998  Renegade mob hitman Michael O'Sullivan--the "A...          2003.0
# 1999                              GILBERT/EAT PRAY LOVE          2007.0
#
#       average_rating  num_pages  ratings_count  \
# 0               5.00       48.0            0.0
# 1               5.00       96.0            1.0
# 2               5.00      222.0            1.0
# 3               5.00      304.0            1.0
# 4               5.00       74.0            5.0
# ...              ...        ...            ...
# 1995            3.55      120.0         4801.0
# 1996            3.55      340.0           11.0
# 1997            3.55      302.0        20216.0
# 1998            3.54       96.0           74.0
# 1999            3.54      368.0      1309623.0
#
#                                               embedding
# 0     [0.05363256856799126, -0.018259329721331596, 0...
# 1     [0.06094173714518547, -0.010597361251711845, 0...
# 2     [0.03172249346971512, 0.03664880990982056, -0....
# 3     [-0.011502875946462154, -0.009286032989621162,...
# 4     [0.004097896162420511, 0.004661967046558857, 0...
# ...                                                 ...
# 1995  [-0.027058351784944534, 0.019854001700878143, ...
# 1996  [0.07347182929515839, -0.028972012922167778, 0...
# 1997  [-0.03379650041460991, 0.0369640588760376, -0....
# 1998  [0.029538720846176147, 0.05673157796263695, -0...
# 1999  [-0.05312195047736168, 0.008585366420447826, -...
#
# [2000 rows x 14 columns]

# %%
df['embedding']=df['embedding'].apply(eval).apply(np.array)

# %%
data = df[['title', 'authors', 'categories']].to_dict('records')
data
# Out:
# [{'title': 'Bill Gates',
#   'authors': 'Sara Barton-Wood',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Ecuador Nature Guide',
#   'authors': 'Christopher D. Jiggins',
#   'categories': 'Botanique'},
#  {'title': 'The Irish Anatomist',
#   'authors': 'Keith Donohue',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Insights',
#   'authors': 'Frederick Lenz',
#   'categories': 'Spiritual life'},
#  {'title': 'The Diamond Color Meditation',
#   'authors': 'John Diamond',
#   'categories': 'Health & Fitness'},
#  {'title': 'Fanning the Flame',
#   'authors': 'Christopher J. H. Wright',
#   'categories': 'Religion'},
#  {'title': 'Harry Potter',
#   'authors': 'J. K. Rowling',
#   'categories': 'Juvenile Fiction'},
#  {'title': "It's a Magical World",
#   'authors': 'Bill Watterson',
#   'categories': 'American wit and humor, Pictorial'},
#  {'title': 'The John Deere Two-Cylinder Tractor Encyclopedia',
#   'authors': 'Don Macmillan;Wayne G. Broehl',
#   'categories': 'Reference'},
#  {'title': 'Empire 2.0',
#   'authors': 'Régis Debray',
#   'categories': 'Political Science'},
#  {'title': 'The Harry Potter Collection',
#   'authors': 'J. K. Rowling',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Homicidal Psycho Jungle Cat',
#   'authors': 'Bill Watterson',
#   'categories': 'Humor'},
#  {'title': 'Zondervan NIV Study Bible',
#   'authors': 'Kenneth L. Barker;Donald W. Burdick',
#   'categories': 'Bibles'},
#  {'title': 'The Price of the Ticket',
#   'authors': 'James Baldwin',
#   'categories': 'Literary Criticism'},
#  {'title': 'The Everyday Life Bible',
#   'authors': 'Joyce Meyer',
#   'categories': 'Bibles'},
#  {'title': 'Marine Conservation Biology',
#   'authors': 'Michael E. Soulé;Michael E. Marine Conservation Biology Institute',
#   'categories': 'Nature'},
#  {'title': 'Restless Till We Rest in You',
#   'authors': 'Saint Augustine, Bishop of Hippo;Thomas Paul Thigpen',
#   'categories': 'Religion'},
#  {'title': 'The New Annotated Sherlock Holmes',
#   'authors': 'Arthur Conan Doyle',
#   'categories': 'Detective and mystery stories, English'},
#  {'title': 'Lego Star Wars',
#   'authors': 'Michael Littlefield;Prima Games',
#   'categories': 'Computers'},
#  {'title': 'The Hobbit / The Lord of the Rings',
#   'authors': 'John Ronald Reuel Tolkien',
#   'categories': 'Fiction'},
#  {'title': 'The Lord of the Rings, the Return of the King',
#   'authors': 'Jude Fisher',
#   'categories': 'Imaginary wars and battles'},
#  {'title': 'Coffin',
#   'authors': 'Yoshitaka Amano;Robert Simpson',
#   'categories': 'Art'},
#  {'title': 'Discovery of the Presence of God',
#   'authors': 'David R. Hawkins',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'Fullmetal Alchemist, Vol. 5',
#   'authors': 'Hiromu Arakawa',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Dewdrops on a Lotus Leaf',
#   'authors': 'Ryōkan;John Stevens',
#   'categories': 'Poetry'},
#  {'title': "Disney's Little Einstein",
#   'authors': 'Susan Ring',
#   'categories': 'Juvenile Fiction'},
#  {'title': "Reader's digest complete guide to the Bible",
#   'authors': "Reader's Digest",
#   'categories': 'Religion'},
#  {'title': 'Simple Acts of Faith',
#   'authors': 'Margaret Feinberg',
#   'categories': 'Religion'},
#  {'title': 'Life Management for Busy Women',
#   'authors': 'Elizabeth George',
#   'categories': 'Religion'},
#  {'title': 'The Making of Star Wars',
#   'authors': 'J. W. Rinzler',
#   'categories': 'Performing Arts'},
#  {'title': 'The Lord of the Rings',
#   'authors': 'Gary Russell',
#   'categories': 'Characters and characteristics in motion pictures'},
#  {'title': 'Transcending the Levels of Consciousness',
#   'authors': 'David R. Hawkins',
#   'categories': 'Religion'},
#  {'title': 'The Lord of the Rings',
#   'authors': 'Chris Smith',
#   'categories': 'Literary Criticism'},
#  {'title': 'The Valley of Vision',
#   'authors': 'Arthur Bennett',
#   'categories': 'Religion'},
#  {'title': 'The Fellowship of the Ring',
#   'authors': 'John Ronald Reuel Tolkien',
#   'categories': 'Fantasy fiction'},
#  {'title': 'The Return of the King',
#   'authors': 'John Ronald Reuel Tolkien',
#   'categories': 'Baggins, Frodo (Fictitious character)'},
#  {'title': 'The Return of the King',
#   'authors': 'J. R. R. Tolkien',
#   'categories': 'Baggins, Frodo (Fictitious character)'},
#  {'title': 'I Am that',
#   'authors': 'Sri Nisargadatta Maharaj;Sudhakar S. Dikshit',
#   'categories': 'Philosophy'},
#  {'title': 'The Lord of the Rings',
#   'authors': 'Jude Fisher',
#   'categories': 'Fiction'},
#  {'title': "Children's Christmas Stories and Poems",
#   'authors': 'Candace Ward',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Learning to Love',
#   'authors': 'Thomas Merton',
#   'categories': 'Religion'},
#  {'title': 'Night Lives',
#   'authors': 'Phyllis Eisenstein;Alex Eisenstein',
#   'categories': 'Fiction'},
#  {'title': 'Diary Of Virginia Woolf Volume 5',
#   'authors': 'Virginia Woolf',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Collected Letters of C.S. Lewis, Volume 3',
#   'authors': 'C. S. Lewis',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Fate of Reason',
#   'authors': 'Frederick C. Beiser',
#   'categories': 'Philosophy'},
#  {'title': 'Red Dragon',
#   'authors': 'Thomas Harris',
#   'categories': 'Adventure stories'},
#  {'title': 'Harry Potter and Philosophy',
#   'authors': 'David Baggett;Shawn Klein;William Irwin',
#   'categories': 'Fiction'},
#  {'title': 'Sister Outsider',
#   'authors': 'Professor Audre Lorde;Audre Lorde',
#   'categories': 'Social Science'},
#  {'title': 'Harry Bosch Novels, The: Volume 2',
#   'authors': 'Michael Connelly',
#   'categories': 'Fiction'},
#  {'title': 'Αλκηστισ',
#   'authors': 'Euripides',
#   'categories': 'Alcestis (Greek mythology)'},
#  {'title': 'Bird Songs', 'authors': 'Les Beletsky', 'categories': 'Nature'},
#  {'title': 'EntreMundos/AmongWorlds',
#   'authors': 'AnaLouise Keating',
#   'categories': 'Literary Collections'},
#  {'title': 'New York 2000',
#   'authors': 'Robert A. M. Stern;David Fishman;Jacob Tilove',
#   'categories': 'Architecture'},
#  {'title': 'Seabiscuit',
#   'authors': 'B. K. Beckwith',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Labyrinths',
#   'authors': 'Jorge Luis Borges',
#   'categories': 'Classical fiction'},
#  {'title': 'Love', 'authors': 'Pablo Neruda', 'categories': 'Poetry'},
#  {'title': 'The Lord of the Rings',
#   'authors': 'Brian Sibley',
#   'categories': 'Performing Arts'},
#  {'title': 'Stars in Their Courses',
#   'authors': 'Shelby Foote',
#   'categories': 'History'},
#  {'title': 'Call of Cthulhu RPG',
#   'authors': 'Sandy Petersen;Lynn Willis',
#   'categories': 'Games'},
#  {'title': 'Lover Awakened', 'authors': 'J. R. Ward', 'categories': 'Fiction'},
#  {'title': 'Always Enough',
#   'authors': 'Rolland Baker;Heidi Baker',
#   'categories': 'Religion'},
#  {'title': "God's Generals",
#   'authors': 'Roberts Liardon',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Beauty',
#   'authors': "John O'Donohue",
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'There is Always Enough',
#   'authors': 'Rolland Baker;Heidi Baker',
#   'categories': 'Church work with the poor'},
#  {'title': 'Drop the Rock',
#   'authors': 'Bill P.;Todd W.;Sara S.',
#   'categories': 'Self-Help'},
#  {'title': 'Hungry Planet',
#   'authors': "Peter Menzel;Faith D'Aluisio",
#   'categories': 'Cooking'},
#  {'title': 'Herzog on Herzog',
#   'authors': 'Paul Cronin',
#   'categories': 'Performing Arts'},
#  {'title': "James Herriot's Treasury for Children",
#   'authors': 'James Herriot',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'More Plums in One',
#   'authors': 'Janet Evanovich',
#   'categories': 'Fiction'},
#  {'title': 'The Munsters',
#   'authors': 'Stephen Cox',
#   'categories': 'Performing Arts'},
#  {'title': 'The Two Towers',
#   'authors': 'John Ronald Reuel Tolkien',
#   'categories': 'Fiction'},
#  {'title': "The Complete Monty Python's Flying Circus",
#   'authors': 'Graham Chapman;Monty Python (Comedy troupe);Terry Gilliam;Eric Idle;Terry Jones',
#   'categories': 'Humor'},
#  {'title': 'The Two Towers',
#   'authors': 'John Ronald Reuel Tolkien',
#   'categories': 'Fiction'},
#  {'title': 'Homelands',
#   'authors': 'Patricia Justine Tumang;Jenesha de Rivera',
#   'categories': 'Social Science'},
#  {'title': "Tucket's Travels",
#   'authors': 'Gary Paulsen',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Last Lion',
#   'authors': 'William Manchester',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'C. S. Lewis',
#   'authors': 'Bruce L. Edwards',
#   'categories': 'Literary Criticism'},
#  {'title': 'History of Religious Ideas, Volume 3',
#   'authors': 'Mircea Eliade',
#   'categories': 'Religion'},
#  {'title': 'The Border Trilogy',
#   'authors': 'Cormac McCarthy',
#   'categories': 'Fiction'},
#  {'title': 'Selected Verse',
#   'authors': 'Federico García Lorca;Christopher Maurer;Catherine Brown',
#   'categories': 'Poetry'},
#  {'title': 'Band of Brothers',
#   'authors': 'Stephen E. Ambrose',
#   'categories': 'History'},
#  {'title': 'The Complete Collected Poems of Maya Angelou',
#   'authors': 'Maya Angelou',
#   'categories': 'Poetry'},
#  {'title': 'The Corner',
#   'authors': 'David Simon;Edward Burns',
#   'categories': 'Social Science'},
#  {'title': 'The Glory and the Dream',
#   'authors': 'William Manchester',
#   'categories': 'History'},
#  {'title': 'Imajica II', 'authors': 'Clive Barker', 'categories': 'Fiction'},
#  {'title': 'Myths of Light',
#   'authors': 'Joseph Campbell',
#   'categories': 'Philosophy'},
#  {'title': "Where I'm Calling from",
#   'authors': 'Raymond Carver',
#   'categories': 'Fiction'},
#  {'title': 'Gates Of Fire',
#   'authors': 'Steven Pressfield',
#   'categories': 'Fiction'},
#  {'title': 'Dark Rivers of the Heart/Intensity/Sole Survivor',
#   'authors': 'Dean Koontz',
#   'categories': 'Fiction'},
#  {'title': 'Empires of the Monsoon',
#   'authors': 'Richard Hall',
#   'categories': 'Africa, East'},
#  {'title': '"Gorgias" and "Phaedrus"',
#   'authors': 'Plato',
#   'categories': 'Philosophy'},
#  {'title': 'Shattered Sword',
#   'authors': 'Jonathan B. Parshall;Anthony P. Tully',
#   'categories': 'History'},
#  {'title': '100 Love Sonnets',
#   'authors': 'Pablo Neruda',
#   'categories': 'Poetry'},
#  {'title': 'Blink-182',
#   'authors': 'Blink-182;Anne Hoppus;Tom Delonge;Mark Hoppus;Travis Barker',
#   'categories': 'Biography & Autobiography'},
#  {'title': "James Herriot's Dog Stories",
#   'authors': 'James Herriot',
#   'categories': 'Pets'},
#  {'title': 'Feminist Measures',
#   'authors': 'Lynn Keller;Cristanne Miller',
#   'categories': 'Social Science'},
#  {'title': 'The Best of Wodehouse',
#   'authors': 'Pelham Grenville Wodehouse',
#   'categories': 'Fiction'},
#  {'title': 'Healing with Whole Foods',
#   'authors': 'Paul Pitchford',
#   'categories': 'Health & Fitness'},
#  {'title': 'Shadow of the Almighty',
#   'authors': 'Elisabeth Elliot',
#   'categories': 'Religion'},
#  {'title': 'Stormie',
#   'authors': 'Stormie Omartian',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Plato in twelve volumes',
#   'authors': 'Plato',
#   'categories': 'Literary Criticism'},
#  {'title': 'Long Walk to Freedom',
#   'authors': 'Nelson Mandela',
#   'categories': 'Apartheid'},
#  {'title': "Reinventing the Enemy's Language",
#   'authors': 'Joy Harjo;Gloria Bird',
#   'categories': 'Fiction'},
#  {'title': 'And The Band Played on',
#   'authors': 'Randy Shilts',
#   'categories': 'Health & Fitness'},
#  {'title': 'Manic-Depressive Illness',
#   'authors': 'Frederick K. Goodwin;Kay Redfield Jamison',
#   'categories': 'Medical'},
#  {'title': 'Collected tales, sketches, speeches, and essays 1891-1910',
#   'authors': 'Mark Twain',
#   'categories': 'Humorous stories, American'},
#  {'title': "Selections from Homer's Iliad",
#   'authors': 'Homer',
#   'categories': 'Literary Criticism'},
#  {'title': 'Candy Licker', 'authors': 'Noire', 'categories': 'Fiction'},
#  {'title': 'Maus II',
#   'authors': 'Art Spiegelman',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Christianity for Modern Pagans',
#   'authors': 'Peter Kreeft',
#   'categories': 'Religion'},
#  {'title': 'Enchanted Evening',
#   'authors': 'M. M. Kaye',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Latin Via Ovid',
#   'authors': 'Norma Goldman;Jacob E. Nyenhuis',
#   'categories': 'Foreign Language Study'},
#  {'title': 'Code', 'authors': 'Charles Petzold', 'categories': 'Computers'},
#  {'title': 'Heart and Hands',
#   'authors': 'Elizabeth Davis',
#   'categories': 'Health & Fitness'},
#  {'title': 'Peanuts', 'authors': 'Charles M. Schulz', 'categories': 'Art'},
#  {'title': 'Going Postal',
#   'authors': 'Terry Pratchett',
#   'categories': 'Fiction'},
#  {'title': 'Brevity & echo',
#   'authors': 'Kathleen Rooney',
#   'categories': 'Fiction'},
#  {'title': 'The Secret Lives of Men and Women',
#   'authors': 'Frank Warren',
#   'categories': 'Self-Help'},
#  {'title': 'Where the Red Fern Grows',
#   'authors': 'Wilson Rawls',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Diary of Virginia Woolf',
#   'authors': 'Virginia Woolf',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Speeches and Writings 1832-1858',
#   'authors': 'Abraham Lincoln',
#   'categories': 'Illinois'},
#  {'title': 'The Orwell Reader',
#   'authors': 'George Orwell',
#   'categories': 'Literary Collections'},
#  {'title': 'The Collected Letters of C.S. Lewis, Volume 1',
#   'authors': 'C. S. Lewis',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Historical Romances',
#   'authors': 'Mark Twain;Samuel Langhorne Clemens;Victor and Lin Salamo editors Fischer;Susan K. Harris;Susan R. Harris',
#   'categories': 'Fiction'},
#  {'title': 'The Marvel Comics Encyclopedia',
#   'authors': 'DK Publishing, Inc',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Caesar', 'authors': 'Colleen McCullough', 'categories': 'Fiction'},
#  {'title': 'A Fine Balance',
#   'authors': 'Rohinton Mistry',
#   'categories': 'Fiction'},
#  {'title': "Will Eisner's New York",
#   'authors': 'Will Eisner',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'A fine balance',
#   'authors': 'Rohinton Mistry',
#   'categories': 'Fiction'},
#  {'title': "Man's Search for Meaning",
#   'authors': 'Viktor Emil Frankl',
#   'categories': 'Psychology'},
#  {'title': 'Lover Eternal', 'authors': 'J. R. Ward', 'categories': 'Fiction'},
#  {'title': "Anton Chekhov's Short Stories",
#   'authors': 'Anton Pavlovich Chekhov;Ralph E. Matlaw',
#   'categories': 'Fiction'},
#  {'title': 'The Fellowship of the Ring',
#   'authors': 'John Ronald Reuel Tolkien',
#   'categories': 'Fiction'},
#  {'title': 'Shakespeare A to Z',
#   'authors': 'Charles Boyce;David Allen White',
#   'categories': 'Drama'},
#  {'title': 'The Grand Inquisitor',
#   'authors': 'Fyodor Dostoyevsky;Charles B. Guignon',
#   'categories': 'Political Science'},
#  {'title': 'In the Name of Jesus',
#   'authors': 'Henri J. M. Nouwen',
#   'categories': 'Religion'},
#  {'title': 'Ludwig Wittgenstein',
#   'authors': 'Ray Monk',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Epictetus', 'authors': 'Epictetus', 'categories': 'Philosophy'},
#  {'title': 'Diary of a Mistress',
#   'authors': 'Miasha',
#   'categories': 'Fiction'},
#  {'title': "A Primate's Memoir",
#   'authors': 'Robert M. Sapolsky',
#   'categories': 'Nature'},
#  {'title': 'The Fellowship of the Ring',
#   'authors': 'J. R. R. Tolkien',
#   'categories': 'Fiction'},
#  {'title': 'Battle Cry of Freedom',
#   'authors': 'James M. McPherson',
#   'categories': 'History'},
#  {'title': 'Another Day in Paradise',
#   'authors': 'Jim Toomey',
#   'categories': 'Humor'},
#  {'title': 'The Plague', 'authors': 'Albert Camus', 'categories': 'Fiction'},
#  {'title': 'My secret',
#   'authors': 'Frank Warren',
#   'categories': 'Antiques & Collectibles'},
#  {'title': 'The Harry Bosch Novels',
#   'authors': 'Michael Connelly',
#   'categories': 'Fiction'},
#  {'title': 'Terry',
#   'authors': 'Douglas Coupland',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Three by Annie Dillard',
#   'authors': 'Annie Dillard',
#   'categories': 'Fiction'},
#  {'title': "The Best of America's Test Kitchen 2007",
#   'authors': "America's Test Kitchen",
#   'categories': 'Cooking'},
#  {'title': 'Edgar Allan Poe, A to Z',
#   'authors': 'Dawn B. Sova;Branko·Sou閏ek',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Grace Awakening',
#   'authors': 'Charles R. Swindoll',
#   'categories': 'Religion'},
#  {'title': 'Whoreson', 'authors': 'Donald Goines', 'categories': 'Fiction'},
#  {'title': 'Sounds, Feelings, Thoughts',
#   'authors': 'Wisława Szymborska',
#   'categories': 'Poetry'},
#  {'title': 'View with a Grain of Sand',
#   'authors': 'Wisława Szymborska',
#   'categories': 'Polish poetry'},
#  {'title': 'The Hidden Smile of God',
#   'authors': 'John Piper',
#   'categories': 'Religion'},
#  {'title': 'The Neutronium Alchemist',
#   'authors': 'Peter F. Hamilton',
#   'categories': 'Fiction'},
#  {'title': 'Genres in Dialogue',
#   'authors': 'Andrea Wilson Nightingale',
#   'categories': 'Literary Collections'},
#  {'title': 'A Farewell to Arms?',
#   'authors': 'Michael Cox;Adrian Guelke;Fiona Stephen',
#   'categories': 'History'},
#  {'title': 'Orwell in Spain',
#   'authors': 'George Orwell',
#   'categories': 'Fiction'},
#  {'title': 'The Dot and the Line',
#   'authors': 'Norton Juster',
#   'categories': 'Humor'},
#  {'title': 'On Writing',
#   'authors': 'Stephen King',
#   'categories': 'Authors, American'},
#  {'title': 'The Frequencies',
#   'authors': 'Noah Eli Gordon',
#   'categories': 'Poetry'},
#  {'title': 'Six Frigates', 'authors': 'Ian W. Toll', 'categories': 'History'},
#  {'title': 'Providence of a Sparrow',
#   'authors': 'Chris Chester',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Mere Christianity',
#   'authors': 'C. S. Lewis',
#   'categories': 'Religion'},
#  {'title': 'Mapping the World of Harry Potter',
#   'authors': 'Mercedes Lackey;Leah Wilson',
#   'categories': 'Literary Criticism'},
#  {'title': 'Mythology', 'authors': 'Alex Ross', 'categories': 'Art'},
#  {'title': 'Marcel Proust',
#   'authors': 'William C. Carter',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Japan at War',
#   'authors': 'Haruko Taya Cook;Theodore F. Cook',
#   'categories': 'History'},
#  {'title': 'Life Amongst the Modocs',
#   'authors': 'Joaquin Miller',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Killer Angels',
#   'authors': 'Michael Shaara',
#   'categories': 'Fiction'},
#  {'title': 'The Brothers Karamazov',
#   'authors': 'Fyodor Dostoevsky',
#   'categories': 'Fiction'},
#  {'title': 'A Woman in Berlin',
#   'authors': 'Anonymous',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Journals of Sylvia Plath, 1950-1962',
#   'authors': 'Sylvia Plath',
#   'categories': 'Poets, American'},
#  {'title': 'C.S. Lewis', 'authors': 'C. S. Lewis', 'categories': 'Religion'},
#  {'title': 'Sword & Citadel',
#   'authors': 'Gene Wolfe',
#   'categories': 'Fiction'},
#  {'title': "Keats's Poetry and Prose",
#   'authors': 'John Keats',
#   'categories': 'Poetry'},
#  {'title': 'Vladimir Nabokov',
#   'authors': 'Brian Boyd',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Code Book', 'authors': 'Simon Singh', 'categories': 'History'},
#  {'title': 'Pretty Things',
#   'authors': 'Liz Goldwyn',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Huxley and God',
#   'authors': 'Aldous Huxley',
#   'categories': 'Religion'},
#  {'title': 'Balanchine',
#   'authors': 'Bernard Taper',
#   'categories': 'Biography & Autobiography'},
#  {'title': "Albion's Seed",
#   'authors': 'David Hackett Fischer',
#   'categories': 'Fiction'},
#  {'title': 'The Art of Richard P. Feynman',
#   'authors': 'Richard Phillips Feynman',
#   'categories': 'Art'},
#  {'title': 'The World of Mr. Mulliner',
#   'authors': 'Pelham Grenville Wodehouse',
#   'categories': 'Humorous stories, English'},
#  {'title': "The Survivor's Guide to Sex",
#   'authors': 'Staci Haines',
#   'categories': 'Self-Help'},
#  {'title': 'The Best of H.P. Lovecraft',
#   'authors': 'H. P. Lovecraft',
#   'categories': 'Fiction'},
#  {'title': 'Elder Scrolls IV',
#   'authors': 'Peter Olafson',
#   'categories': 'Games'},
#  {'title': 'The Poetry of Robert Frost',
#   'authors': 'Robert Frost',
#   'categories': 'Poetry'},
#  {'title': 'Mother Maria Skobtsova',
#   'authors': 'Mariia',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Writer of Modern Life',
#   'authors': 'Walter Benjamin',
#   'categories': 'Literary Criticism'},
#  {'title': "Janet Flanner's world",
#   'authors': 'Janet Flanner;Irving Drutman',
#   'categories': 'Fiction'},
#  {'title': 'The Great Book of Amber',
#   'authors': 'Roger Zelazny',
#   'categories': 'Fiction'},
#  {'title': 'Lover Revealed',
#   'authors': 'J. R. Ward;Jessica Bird Ward',
#   'categories': 'Fiction'},
#  {'title': "You Can't be Neutral on a Moving Train",
#   'authors': 'Howard Zinn',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Demon Princes, Vol. 2',
#   'authors': 'Jack Vance',
#   'categories': 'Fiction'},
#  {'title': 'Moonage Daydream',
#   'authors': 'David Bowie',
#   'categories': 'Music'},
#  {'title': 'The Transition of H.P. Lovecraft',
#   'authors': 'Howard Phillips Lovecraft',
#   'categories': 'Fiction'},
#  {'title': 'Yes, Your Teen Is Crazy!',
#   'authors': 'Michael J. Bradley',
#   'categories': 'Family & Relationships'},
#  {'title': 'Cat Cross Their Graves',
#   'authors': 'Shirley Rousseau Murphy',
#   'categories': 'Fiction'},
#  {'title': "Laura's Album",
#   'authors': 'William Anderson',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Jesus and the Eyewitnesses',
#   'authors': 'Richard Bauckham',
#   'categories': 'Religion'},
#  {'title': 'Tom Stoppard: Plays 5',
#   'authors': 'Tom Stoppard',
#   'categories': 'Drama'},
#  {'title': 'Lirael', 'authors': 'Garth Nix', 'categories': 'Fantasy fiction'},
#  {'title': 'Three Philosophies of Life',
#   'authors': 'Peter Kreeft',
#   'categories': 'Religion'},
#  {'title': 'Star Wars',
#   'authors': 'Kristin Lund;Simon Beecroft;Kerrie Dougherty',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': "Ovid's Metamorphoses",
#   'authors': 'Ovid',
#   'categories': 'Social Science'},
#  {'title': 'Eight Mindful Steps to Happiness',
#   'authors': 'Henepola Gunaratana',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'The Sword of Truth',
#   'authors': 'Terry Goodkind',
#   'categories': 'Fiction'},
#  {'title': 'Tsubasa',
#   'authors': 'CLAMP (Mangaka group)',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Foghorn Outdoors Pacific Northwest Hiking',
#   'authors': 'Scott Leonard;Megan McMorris',
#   'categories': 'Sports & Recreation'},
#  {'title': 'Life of the Beloved',
#   'authors': 'Henri J. M. Nouwen',
#   'categories': 'Religion'},
#  {'title': "Maud Hart Lovelace's Deep Valley",
#   'authors': 'Julie A. Schrader',
#   'categories': 'Authors, American'},
#  {'title': 'The Complete Short Stories Of Ernest Hemingway',
#   'authors': 'Ernest Hemingway',
#   'categories': 'Fiction'},
#  {'title': 'Death of a Naturalist',
#   'authors': 'Seamus Heaney',
#   'categories': 'Poetry'},
#  {'title': 'Revenge of the Lawn',
#   'authors': 'Richard Brautigan',
#   'categories': 'Fiction'},
#  {'title': 'Cathedral', 'authors': 'Raymond Carver', 'categories': 'Fiction'},
#  {'title': 'Berlin Diary',
#   'authors': 'William L. Shirer',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Gardening with a Wild Heart',
#   'authors': 'Judith Larner Lowry',
#   'categories': 'Gardening'},
#  {'title': 'The DC Comics Encyclopedia',
#   'authors': 'Phil Jimenez',
#   'categories': 'Antiques & Collectibles'},
#  {'title': 'Great Speeches by African Americans',
#   'authors': 'James Daley',
#   'categories': 'Social Science'},
#  {'title': 'Moon in a Dewdrop',
#   'authors': 'Dōgen;Zen Master Dogen',
#   'categories': 'Philosophy'},
#  {'title': 'The Secret Garden Cookbook',
#   'authors': 'Amy Cotler',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Anne Frank Remembered',
#   'authors': 'Miep Gies;Alison Leslie Gold',
#   'categories': 'History'},
#  {'title': 'The Power of One',
#   'authors': 'John C. Maxwell;Thomas G. Addington',
#   'categories': 'Business & Economics'},
#  {'title': 'Molloy', 'authors': 'Samuel Beckett', 'categories': 'Fiction'},
#  {'title': "Stephen Hawking's Universe",
#   'authors': 'David Filkin',
#   'categories': 'Science'},
#  {'title': 'The Buddha in Your Mirror',
#   'authors': 'Woody Hochswender;Greg Martin;Ted Morino',
#   'categories': 'Religion'},
#  {'title': 'Borderlands',
#   'authors': 'Gloria Anzaldúa',
#   'categories': 'Literary Collections'},
#  {'title': 'The Gramsci Reader',
#   'authors': 'Antonio Gramsci',
#   'categories': 'Philosophy'},
#  {'title': 'The Truth', 'authors': 'Terry Pratchett', 'categories': 'Drama'},
#  {'title': 'Echoes of the Soul',
#   'authors': 'Echo Bodine',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': '"Surely You\'re Joking, Mr. Feynman!"',
#   'authors': 'Richard Phillips Feynman;Ralph Leighton',
#   'categories': 'Biography & Autobiography'},
#  {'title': "In Harm's Way",
#   'authors': 'Doug Stanton',
#   'categories': 'History'},
#  {'title': 'Tim Burton',
#   'authors': 'Tim Burton',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Lord of the Rings and Philosophy',
#   'authors': 'Gregory Bassham;Eric Bronson',
#   'categories': 'Literary Criticism'},
#  {'title': 'Regeneration Through Violence',
#   'authors': 'Richard Slotkin',
#   'categories': 'Literary Criticism'},
#  {'title': 'The Wave in the Mind',
#   'authors': 'Ursula K. Le Guin',
#   'categories': 'Literary Collections'},
#  {'title': 'History of the Peloponnesian War',
#   'authors': 'Thucydides',
#   'categories': 'History'},
#  {'title': 'The Blazing Center Study Guide',
#   'authors': 'John Piper;Desiring God',
#   'categories': 'Religion'},
#  {'title': '"Surely You\'re Joking, Mr. Feynman!"',
#   'authors': 'Richard Phillips Feynman;Ralph Leighton',
#   'categories': 'Physicists'},
#  {'title': 'Team of Rivals',
#   'authors': 'Doris Kearns Goodwin',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Common Ground',
#   'authors': 'J. Anthony Lukas',
#   'categories': 'Education'},
#  {'title': "A Supposedly Fun Thing I'll Never Do Again",
#   'authors': 'David Foster Wallace',
#   'categories': 'Popular culture'},
#  {'title': "A Supposedly Fun Thing I'll Never Do Again",
#   'authors': 'David Foster Wallace',
#   'categories': 'Humor'},
#  {'title': '"What Do You Care what Other People Think?"',
#   'authors': 'Richard Phillips Feynman;Ralph Leighton',
#   'categories': 'BIOGRAPHY & AUTOBIOGRAPHY'},
#  {'title': 'Darth Bane', 'authors': 'Drew Karpyshyn', 'categories': 'Fiction'},
#  {'title': 'Tai-Pan', 'authors': 'James Clavell', 'categories': 'Fiction'},
#  {'title': 'Bury the Chains',
#   'authors': 'Adam Hochschild',
#   'categories': 'History'},
#  {'title': "The Dragon Doesn't Live Here Anymore",
#   'authors': 'Alan Cohen',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'Performance Assessments for Adult Education',
#   'authors': 'Dan Birlew',
#   'categories': 'Games & Activities'},
#  {'title': 'Modern Mind', 'authors': 'Peter Watson', 'categories': 'Science'},
#  {'title': "Hamlet's Mill",
#   'authors': 'Giorgio De Santillana;Hertha von Dechend',
#   'categories': 'Philosophy'},
#  {'title': "Will You Miss Me When I'm Gone?",
#   'authors': 'Mark Zwonitzer;Charles Hirshberg',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Exclusion and Embrace',
#   'authors': 'Miroslav Volf',
#   'categories': 'Religion'},
#  {'title': 'The Vampire Chronicles Collection',
#   'authors': 'Anne Rice',
#   'categories': 'Fiction'},
#  {'title': 'Tending Lives', 'authors': 'Echo Heron', 'categories': 'Medical'},
#  {'title': 'The demon-haunted world',
#   'authors': 'Carl Sagan',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'A Small Pinch of Weather',
#   'authors': 'Joan Aiken',
#   'categories': "Children's stories, English"},
#  {'title': 'Berlioz',
#   'authors': 'David Cairns',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'I, Claudius', 'authors': 'Robert Graves', 'categories': 'Fiction'},
#  {'title': 'New Threads in the Pattern',
#   'authors': 'Robert Jordan',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Alanna',
#   'authors': 'Tamora Pierce',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Letters, Summer 1926',
#   'authors': 'Boris Leonidovich Pasternak;Marina T︠S︡vetaeva;Rainer Maria Rilke;Margaret Wettlin;Walter W. Arndt;Jamey Gambrell',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'No Price Too High',
#   'authors': 'Alex Jones',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Lamb', 'authors': 'Christopher Moore', 'categories': 'Fiction'},
#  {'title': 'The Glass Castle',
#   'authors': 'Jeannette Walls',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The BFG',
#   'authors': 'Roald Dahl;David Wood;Jane Walmsley',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': "Your Child's Self-esteem",
#   'authors': 'Dorothy Corkille Briggs',
#   'categories': 'Family & Relationships'},
#  {'title': 'Magician', 'authors': 'Raymond E. Feist', 'categories': 'Fiction'},
#  {'title': 'Lovingkindness',
#   'authors': 'Sharon Salzberg;Jon Kabat-Zinn',
#   'categories': 'Self-Help'},
#  {'title': 'Sherlock Holmes',
#   'authors': 'Nick Rennison',
#   'categories': 'Fiction'},
#  {'title': 'Rabbit Angstrom',
#   'authors': 'John Updike',
#   'categories': 'Fiction'},
#  {'title': 'Declarations of Independence',
#   'authors': 'Howard Zinn',
#   'categories': 'Political science'},
#  {'title': 'The Princess Bride',
#   'authors': 'William Goldman',
#   'categories': 'Fiction'},
#  {'title': 'The Legacy of Sovereign Joy',
#   'authors': 'John Piper',
#   'categories': 'Religion'},
#  {'title': "Shakespeare's Sonnets",
#   'authors': 'William Shakespeare',
#   'categories': 'Drama'},
#  {'title': "A Writer's Diary",
#   'authors': 'Virginia Woolf;Leonard Woolf',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Phantoms in the Brain',
#   'authors': 'V. S. Ramachandran',
#   'categories': 'Medical'},
#  {'title': 'Education As My Agenda',
#   'authors': 'Gertrude S. Williams;Jo Ann Robinson',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Salonica, City of Ghosts',
#   'authors': 'Mark Mazower',
#   'categories': 'History'},
#  {'title': 'Pathologies of Power',
#   'authors': 'Paul Farmer',
#   'categories': 'History'},
#  {'title': 'Winterdance', 'authors': 'Gary Paulsen', 'categories': 'Pets'},
#  {'title': "Guardians of Ga'hoole",
#   'authors': 'Kathryn Lasky',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Cat in the Dark',
#   'authors': 'Shirley Rousseau Murphy',
#   'categories': 'Fiction'},
#  {'title': 'The Dragon Reborn',
#   'authors': 'Robert Jordan',
#   'categories': 'Fiction'},
#  {'title': 'The Pleasure of Finding Things Out',
#   'authors': 'Richard Phillips Feynman',
#   'categories': 'Science'},
#  {'title': 'The Richness of Life',
#   'authors': 'Stephen Jay Gould',
#   'categories': 'Science'},
#  {'title': 'The Nature of Play',
#   'authors': 'Anthony D. Pellegrini;Peter K. Smith',
#   'categories': 'Psychology'},
#  {'title': 'Pygmalion',
#   'authors': 'Bernard Shaw;Alan Jay Lerner',
#   'categories': 'Fiction'},
#  {'title': 'The Autobiography of Henry VIII',
#   'authors': 'Margaret George',
#   'categories': 'Fiction'},
#  {'title': 'We Wish to Inform You That Tomorrow We Will Be Killed with Our Families',
#   'authors': 'Philip Gourevitch',
#   'categories': 'History'},
#  {'title': 'Here, There and Everywhere',
#   'authors': 'Geoff Emerick;Howard Massey',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Consider the Lobster',
#   'authors': 'David Foster Wallace',
#   'categories': 'Literary Criticism & Collections'},
#  {'title': 'In Focus',
#   'authors': 'National Geographic Society (U.S.)',
#   'categories': 'Photography'},
#  {'title': 'BFF', 'authors': 'Judy Blume', 'categories': 'Juvenile Fiction'},
#  {'title': "Tell Me how Long the Train's Been Gone",
#   'authors': 'James Baldwin',
#   'categories': 'Fiction'},
#  {'title': 'The Confusion',
#   'authors': 'Neal Stephenson',
#   'categories': 'Fiction'},
#  {'title': 'The Demon Princes, Vol. 1',
#   'authors': 'Jack Vance',
#   'categories': 'Fiction'},
#  {'title': "Richard Brautigan's A Confederate General from Big Sur, Dreaming of Babylon, and The Hawkline Monster",
#   'authors': 'Richard Brautigan',
#   'categories': 'Fiction'},
#  {'title': 'Good Omens',
#   'authors': 'Neil Gaiman;Terry Pratchett',
#   'categories': 'Fiction'},
#  {'title': 'Nancy Drew Starter Set',
#   'authors': 'Carolyn Keene',
#   'categories': 'Juvenile Fiction'},
#  {'title': "Little Pilgrim's Progress",
#   'authors': 'Helen L. Taylor',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'James Tiptree, Jr.',
#   'authors': 'Julie Phillips',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Marriage of Heaven and Hell',
#   'authors': 'William Blake',
#   'categories': 'Art'},
#  {'title': 'Click, Clack, Moo',
#   'authors': 'Doreen Cronin;Betsy Lewin',
#   'categories': "Children's stories"},
#  {'title': "All the Shah's Men",
#   'authors': 'Stephen Kinzer',
#   'categories': 'History'},
#  {'title': 'Power, Sex, Suicide',
#   'authors': 'Nick Lane',
#   'categories': 'Science'},
#  {'title': 'Achilles in Vietnam',
#   'authors': 'Jonathan Shay',
#   'categories': 'Psychology'},
#  {'title': 'Star Wars Republic Commando',
#   'authors': 'Karen Traviss',
#   'categories': 'Fiction'},
#  {'title': 'A Life in Letters',
#   'authors': 'F. Scott Fitzgerald',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Three Complete Novels',
#   'authors': 'Lloyd Alexander',
#   'categories': 'Juvenile Fiction'},
#  {'title': "Fermat's Enigma",
#   'authors': 'Simon Singh',
#   'categories': 'Mathematics'},
#  {'title': 'Teach Them Diligently',
#   'authors': 'Louis Paul Priolo',
#   'categories': 'Religion'},
#  {'title': 'The Presocratic Philosophers',
#   'authors': 'G. S. Kirk;J. E. Raven;M. Schofield',
#   'categories': 'Philosophy'},
#  {'title': 'Manufacturing Consent',
#   'authors': 'Edward S. Herman;Noam Chomsky',
#   'categories': 'Political Science'},
#  {'title': 'Discovering Great Artists',
#   'authors': 'MaryAnn F. Kohl;Kim Solga;Rebecca Van Slyke',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'The Invisibles',
#   'authors': 'Grant Morrison;Chris Weston;Ivan Reis;Ray Kryssing',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Silenced', 'authors': 'Jerry B. Jenkins', 'categories': 'Fiction'},
#  {'title': 'Perfectly Reasonable Deviations from the Beaten Track',
#   'authors': 'Richard Phillips Feynman',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Savage Inequalities',
#   'authors': 'Jonathan Kozol',
#   'categories': 'Education'},
#  {'title': 'High performance MySQL',
#   'authors': 'Jeremy D. Zawodny;Derek J. Balling',
#   'categories': 'Computers'},
#  {'title': 'If Beale Street Could Talk',
#   'authors': 'James Baldwin',
#   'categories': 'Fiction'},
#  {'title': "Don't Make Me Think!",
#   'authors': 'Steve Krug',
#   'categories': 'Computers'},
#  {'title': 'Laura Ingalls Wilder Country',
#   'authors': 'William Anderson;William T Anderson, Ed.',
#   'categories': 'History'},
#  {'title': 'The Passion of Jesus Christ',
#   'authors': 'John Piper',
#   'categories': 'Religion'},
#  {'title': 'Tales from Ovid',
#   'authors': 'Ovid;Ted Hughes',
#   'categories': 'Latin poetry'},
#  {'title': 'The Murder of Roger Ackroyd',
#   'authors': 'Agatha Christie',
#   'categories': 'Fiction'},
#  {'title': 'Ride of the Second Horseman',
#   'authors': "Robert L. O'Connell",
#   'categories': 'History'},
#  {'title': 'The Phenomenon of Life',
#   'authors': 'Hans Jonas;Eleonore Jonas',
#   'categories': 'Philosophy'},
#  {'title': 'The Short Stories of F. Scott Fitzgerald',
#   'authors': 'F. Scott Fitzgerald',
#   'categories': 'Fiction'},
#  {'title': 'Black Lamb and Grey Falcon',
#   'authors': 'Rebecca West',
#   'categories': 'History'},
#  {'title': 'Philosophical Investigations',
#   'authors': 'Ludwig Wittgenstein',
#   'categories': 'Philosophy'},
#  {'title': 'The Myth of the Eternal Return',
#   'authors': 'Mircea Eliade',
#   'categories': 'Social Science'},
#  {'title': 'Sailing Alone Around the Room',
#   'authors': 'Billy Collins',
#   'categories': 'Poetry'},
#  {'title': "Their Sisters' Keepers",
#   'authors': 'Estelle B. Freedman',
#   'categories': 'History'},
#  {'title': 'The Shadow Rising',
#   'authors': 'Robert Jordan',
#   'categories': 'Fiction'},
#  {'title': 'Women & Cats', 'authors': 'Michelle Lovric', 'categories': 'Pets'},
#  {'title': 'It', 'authors': 'Stephen King', 'categories': 'Fiction'},
#  {'title': 'The diaries',
#   'authors': 'Franz Kafka',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Out-of-sync Child Has Fun',
#   'authors': 'Carol Stock Kranowitz',
#   'categories': 'Family & Relationships'},
#  {'title': 'Unlimited Power',
#   'authors': 'Tony Robbins',
#   'categories': 'Self-Help'},
#  {'title': 'Pink Flamingos, and Other Filth',
#   'authors': 'John Waters',
#   'categories': 'Performing Arts'},
#  {'title': 'This Is Berlin',
#   'authors': 'William L. Shirer;John Keegan',
#   'categories': 'History'},
#  {'title': 'Letters from the Earth',
#   'authors': 'Mark Twain',
#   'categories': 'Literary Criticism'},
#  {'title': 'Playing in the Dark',
#   'authors': 'Toni Morrison',
#   'categories': 'Literary Criticism'},
#  {'title': 'Shamanism',
#   'authors': 'Mircea Eliade',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'John Deere Farm Tractors',
#   'authors': 'Randy Leffingwell',
#   'categories': 'Technology & Engineering'},
#  {'title': 'Happy Endings',
#   'authors': 'Mimi Dietrich',
#   'categories': 'Crafts & Hobbies'},
#  {'title': 'To The Last Man',
#   'authors': 'Jeff Shaara',
#   'categories': 'Fiction'},
#  {'title': 'The Inner Reaches of Outer Space',
#   'authors': 'Joseph Campbell',
#   'categories': 'Religion'},
#  {'title': 'Shibumi', 'authors': 'Trevanian', 'categories': 'Fiction'},
#  {'title': 'The Simple Truth',
#   'authors': 'Philip Levine',
#   'categories': 'Poetry'},
#  {'title': 'Undaunted Courage',
#   'authors': 'Stephen E. Ambrose',
#   'categories': 'Explorers'},
#  {'title': 'Redemption',
#   'authors': 'Steven G. Kellman',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Edie',
#   'authors': 'Melissa Painter;David Weisman',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'EUGENE ONEGIN - A NOVEL IN VERSE V.1',
#   'authors': 'Aleksandr Sergeevich Pushkin',
#   'categories': 'Literary Criticism'},
#  {'title': 'Power Vs. Force',
#   'authors': 'David R. Hawkins',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'Anne of Avonlea',
#   'authors': 'Lucy Maud Montgomery',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Bradbury Chronicles',
#   'authors': 'Sam Weller',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Howl',
#   'authors': 'Allen Ginsberg;Barry Miles',
#   'categories': 'Poetry'},
#  {'title': 'A Savage War of Peace',
#   'authors': 'Alistair Horne',
#   'categories': 'History'},
#  {'title': 'The Last Hours of Ancient Sunlight',
#   'authors': 'Thom Hartmann',
#   'categories': 'Political Science'},
#  {'title': '1000 Rings',
#   'authors': 'Marthe Le Van',
#   'categories': 'Crafts & Hobbies'},
#  {'title': 'Riddle-master',
#   'authors': 'Patricia A. McKillip',
#   'categories': 'Fiction'},
#  {'title': 'Yesterday I Cried',
#   'authors': 'Iyanla Vanzant',
#   'categories': 'Self-Help'},
#  {'title': 'Ancilla to the Pre-Socratic Philosophers',
#   'authors': 'Mary Fitt;Kathleen Freeman',
#   'categories': 'Philosophy'},
#  {'title': 'Death',
#   'authors': 'Neil Gaiman;Chris Bachalo;Mark Buckingham;Mike Dringenberg',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Color Drawing',
#   'authors': 'Michael E. Doyle',
#   'categories': 'Architecture'},
#  {'title': 'The Science of Sherlock Holmes',
#   'authors': 'E. J. Wagner',
#   'categories': 'Law'},
#  {'title': 'Conspiracy of Fools',
#   'authors': 'Kurt Eichenwald',
#   'categories': 'Business & Economics'},
#  {'title': 'Blaming the Victims',
#   'authors': 'Edward W. Said;Christopher Hitchens',
#   'categories': 'History'},
#  {'title': 'Cat Laughing Last',
#   'authors': 'Shirley Rousseau Murphy',
#   'categories': 'Fiction'},
#  {'title': 'The Schopenhauer Cure',
#   'authors': 'Irvin Yalom',
#   'categories': 'Fiction'},
#  {'title': 'Salt in His Shoes',
#   'authors': 'Deloris Jordan;Roslyn M. Jordan',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Touching the Void',
#   'authors': 'Joe Simpson',
#   'categories': 'Sports & Recreation'},
#  {'title': 'The Double Flame',
#   'authors': 'Octavio Paz',
#   'categories': 'Literary Collections'},
#  {'title': 'Doctor Who',
#   'authors': 'Gary Russell',
#   'categories': 'Performing Arts'},
#  {'title': "Lidia's Italy",
#   'authors': 'Tanya Bastianich Manuali',
#   'categories': 'Cooking'},
#  {'title': 'Hope is the Thing with Feathers',
#   'authors': 'Christopher Cokinos',
#   'categories': 'Nature'},
#  {'title': 'Let My People Go Surfing',
#   'authors': 'Yvon Chouinard',
#   'categories': 'Business & Economics'},
#  {'title': 'Scary stories 3',
#   'authors': 'Alvin Schwartz',
#   'categories': 'Folklore'},
#  {'title': 'Gifted Hands',
#   'authors': 'Ben Carson;Cecil B. Murphey',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Fantastic! Wow! and Unreal!',
#   'authors': 'Ruth Heller',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Beyond the Postmodern Mind',
#   'authors': 'Huston Smith',
#   'categories': 'Philosophy'},
#  {'title': 'The Church in Ancient Society',
#   'authors': 'Henry Chadwick',
#   'categories': 'Religion'},
#  {'title': 'Dime-store Alchemy',
#   'authors': 'Charles Simic;Joseph Cornell',
#   'categories': 'Art'},
#  {'title': 'Dispatches from the Tenth Circle',
#   'authors': 'Robert Siegel',
#   'categories': 'Humor'},
#  {'title': 'Miss Marple',
#   'authors': 'Agatha Christie',
#   'categories': 'Detective and mystery stories, English'},
#  {'title': 'Eden',
#   'authors': 'Hiroki Endo',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Poirot', 'authors': 'Agatha Christie', 'categories': 'Authors'},
#  {'title': 'An Episode of Sparrows',
#   'authors': 'Rumer Godden',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Crime and Punishment',
#   'authors': 'Fyodor Dostoyevsky',
#   'categories': 'Fiction'},
#  {'title': 'The Real James Herriot',
#   'authors': 'James Wight;Jim Wight',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Notes from Underground',
#   'authors': 'Fyodor Dostoyevsky',
#   'categories': 'Fiction'},
#  {'title': 'Jesus Freaks',
#   'authors': 'DC Talk (Musical group)',
#   'categories': 'Religion'},
#  {'title': 'The Crusader',
#   'authors': 'Paul Kengor',
#   'categories': 'Political Science'},
#  {'title': 'Letters Home',
#   'authors': 'Sylvia Plath',
#   'categories': 'Authors, American'},
#  {'title': "Kaplan & Sadock's Synopsis of Psychiatry",
#   'authors': 'Benjamin J. Sadock;Virginia A. Sadock',
#   'categories': 'Medical'},
#  {'title': 'Dark Lover', 'authors': 'J. R. Ward', 'categories': 'Fiction'},
#  {'title': 'A Time to Embrace',
#   'authors': 'William Stacy Johnson',
#   'categories': 'Political Science'},
#  {'title': 'Cat Breaking Free',
#   'authors': 'Shirley Rousseau Murphy',
#   'categories': 'Fiction'},
#  {'title': 'Storming the Gates of Paradise',
#   'authors': 'Rebecca Solnit',
#   'categories': 'History'},
#  {'title': 'Odalisque', 'authors': 'Neal Stephenson', 'categories': 'Fiction'},
#  {'title': 'Zora neale Hurston',
#   'authors': 'Henry L. Gates',
#   'categories': 'Literary Criticism'},
#  {'title': 'Shattered Bonds',
#   'authors': 'Dorothy E. Roberts',
#   'categories': 'Political Science'},
#  {'title': "Love's Executioner",
#   'authors': 'Irvin D. Yalom',
#   'categories': 'Existential psychotherapy'},
#  {'title': 'Six Easy Pieces',
#   'authors': 'Richard P. Feynman',
#   'categories': 'Science'},
#  {'title': 'The Apple that Astonished Paris',
#   'authors': 'Billy Collins',
#   'categories': 'American poetry'},
#  {'title': 'Enter Jeeves',
#   'authors': 'P. G. Wodehouse;David A. Jasen',
#   'categories': 'Fiction'},
#  {'title': 'The Wit and Wisdom of Mark Twain',
#   'authors': 'Mark Twain',
#   'categories': 'Literary Criticism'},
#  {'title': 'Teaching a Stone to Talk',
#   'authors': 'Annie Dillard',
#   'categories': 'Literary Criticism'},
#  {'title': 'The Illustrated on the Shoulders of Giants',
#   'authors': 'Stephen W. Hawking',
#   'categories': 'Science'},
#  {'title': 'The Collapse of the Third Republic',
#   'authors': 'William Lawrence Shirer',
#   'categories': 'History'},
#  {'title': 'Plato on Rhetoric and Language',
#   'authors': 'Plato;Jean Nienkamp',
#   'categories': 'Language Arts & Disciplines'},
#  {'title': 'The Complete Short Stories Of Robert Louis Stevenson',
#   'authors': 'Charles Neider;Robert Louis Stevenson',
#   'categories': 'Literary Collections'},
#  {'title': 'The Straight Dope',
#   'authors': 'Cecil Adams;Ed Zotti',
#   'categories': 'Humor'},
#  {'title': 'Seeing Like a State',
#   'authors': 'James C. Scott',
#   'categories': 'Political Science'},
#  {'title': 'The Art of the Personal Essay',
#   'authors': 'Phillip Lopate',
#   'categories': 'Literary Collections'},
#  {'title': 'I. Asimov',
#   'authors': 'Isaac Asimov',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The thief of always',
#   'authors': 'Clive Barker',
#   'categories': 'Fiction'},
#  {'title': "Anne Rice's the Vampire Lestat",
#   'authors': 'Faye Perozich;Anne Rice;Daerick Gross',
#   'categories': 'Humor'},
#  {'title': 'Hot Six',
#   'authors': 'Janet Evanovich',
#   'categories': 'Bail bond agents'},
#  {'title': 'The Rising',
#   'authors': 'Tim LaHaye;Tim F. LaHaye;Jerry B. Jenkins',
#   'categories': 'Fiction'},
#  {'title': 'The Second World War',
#   'authors': 'Martin Gilbert',
#   'categories': 'History'},
#  {'title': 'The Minority Report',
#   'authors': 'Philip K. Dick',
#   'categories': 'Fiction'},
#  {'title': 'I Ching',
#   'authors': 'John Blofeld',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'The Beloved',
#   'authors': 'Kahlil Gibran;John Walbridge',
#   'categories': 'Fiction'},
#  {'title': 'Operating Instructions',
#   'authors': 'Anne Lamott',
#   'categories': 'Family & Relationships'},
#  {'title': 'Sources of the Self',
#   'authors': 'Charles Taylor',
#   'categories': 'Philosophy'},
#  {'title': 'Psychonavigation',
#   'authors': 'John Perkins',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'Speak, Memory',
#   'authors': 'Vladimir Nabokov;Vladimir Vladimirovich Nabokov',
#   'categories': 'Novelists, American'},
#  {'title': 'Reinventing Jesus',
#   'authors': 'J. Ed Komoszewski;M. James Sawyer;Daniel B. Wallace',
#   'categories': 'Religion'},
#  {'title': 'Julian', 'authors': 'Gore Vidal', 'categories': 'Fiction'},
#  {'title': 'Of Time and the River',
#   'authors': 'Thomas Wolfe',
#   'categories': 'Fiction'},
#  {'title': 'Lost Prophet',
#   'authors': "John D'Emilio",
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Absent in the Spring and Other Novels',
#   'authors': 'Mary Westmacott;Agatha Christie',
#   'categories': 'Fiction'},
#  {'title': 'Kaddish and Other Poems: 1958-1960',
#   'authors': 'Allen Ginsberg',
#   'categories': 'Poetry'},
#  {'title': 'Titan',
#   'authors': 'Ron Chernow',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Dr. Seuss Goes to War',
#   'authors': 'Richard H. Minear;Dr. Seuss',
#   'categories': 'History'},
#  {'title': 'Magician',
#   'authors': 'Raymond E. Feist',
#   'categories': 'Apprentices'},
#  {'title': 'The Principles of Psychology',
#   'authors': 'William James',
#   'categories': 'Psychology'},
#  {'title': 'The Guns of August',
#   'authors': 'Barbara Wertheim Tuchman',
#   'categories': 'History'},
#  {'title': "When I Don't Desire God",
#   'authors': 'John Piper',
#   'categories': 'Religion'},
#  {'title': 'Writing Down the Bones',
#   'authors': 'Natalie Goldberg',
#   'categories': 'Self-Help'},
#  {'title': 'What We Talk about when We Talk about Love',
#   'authors': 'Raymond Carver',
#   'categories': 'Fiction'},
#  {'title': 'Forgotten New York',
#   'authors': 'Kevin Walsh',
#   'categories': 'Travel'},
#  {'title': 'Death',
#   'authors': 'Neil Gaiman',
#   'categories': 'Death (Fictitious character : Gaiman)'},
#  {'title': 'The Haunted Screen',
#   'authors': 'Lotte H. Eisner',
#   'categories': 'Performing Arts'},
#  {'title': "A Hard Day's Write, 3e",
#   'authors': 'Steve Turner',
#   'categories': 'Music'},
#  {'title': 'The Heights of Courage',
#   'authors': 'Avigdor Kahalani',
#   'categories': 'History'},
#  {'title': 'Slider',
#   'authors': 'Patrick Robinson',
#   'categories': 'Sports & Recreation'},
#  {'title': 'Think and Grow Rich',
#   'authors': 'Napoleon Hill;Arthur R. Pell',
#   'categories': 'Business & Economics'},
#  {'title': 'Parallel Worlds',
#   'authors': 'Michio Kaku',
#   'categories': 'Science'},
#  {'title': 'Think and Grow Rich: The 21st-Century Edition',
#   'authors': 'Napoleon Hill',
#   'categories': 'Business & Economics'},
#  {'title': 'Not Much Fun',
#   'authors': 'Stuart Y. Silverstein',
#   'categories': 'Biography & Autobiography'},
#  {'title': "Death's Acre",
#   'authors': 'Bill Bass;William M. Bass;Jon Jefferson',
#   'categories': 'True Crime'},
# ...
#  {'title': 'Freaks!', 'authors': 'Steve Miller', 'categories': 'Art'},
#  {'title': 'The Warren Buffett CEO',
#   'authors': 'Robert P. Miles',
#   'categories': 'Business & Economics'},
#  {'title': 'Artemis Fowl',
#   'authors': 'Eoin Colfer',
#   'categories': "Children's stories"},
#  {'title': 'The Politics of Cultural Despair',
#   'authors': 'Fritz R. Stern',
#   'categories': 'History'},
#  {'title': 'Fooled By Randomness',
#   'authors': 'Nassim Taleb',
#   'categories': 'Business & Economics'},
#  {'title': 'Blame It on the Brain?',
#   'authors': 'Edward T. Welch',
#   'categories': 'Medical'},
#  {'title': 'Propaganda and the Public Mind',
#   'authors': 'David Barsamian;Noam Chomsky',
#   'categories': 'Language and languages'},
#  {'title': 'Beauty', 'authors': 'Robin McKinley', 'categories': 'Fairy tales'},
#  {'title': 'Plato on Love',
#   'authors': 'Plato;C. D. C. Reeve',
#   'categories': 'Philosophy'},
#  {'title': 'The Historical Atlas of New York City, Second Edition',
#   'authors': 'Eric Homberger',
#   'categories': 'History'},
#  {'title': 'Your First Year in Network Marketing',
#   'authors': 'Mark Yarnell;Rene Reid Yarnell;Rene Yarnell',
#   'categories': 'Business & Economics'},
#  {'title': 'For the Sins of My Father',
#   'authors': 'Albert DeMeo;Mary Jane Ross',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Saint-Exupery',
#   'authors': 'Stacy Schiff',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Eternal Frontier',
#   'authors': 'Tim Flannery',
#   'categories': 'History'},
#  {'title': 'The Language Instinct',
#   'authors': 'Steven Pinker',
#   'categories': 'Language Arts & Disciplines'},
#  {'title': 'Expelled from Eden',
#   'authors': 'Perseus',
#   'categories': 'Fiction'},
#  {'title': 'The Poisonwood Bible',
#   'authors': 'Barbara Kingsolver',
#   'categories': 'Fiction'},
#  {'title': 'The Franco-Prussian War',
#   'authors': 'Michael Howard',
#   'categories': 'Foreign Language Study'},
#  {'title': 'An Unquiet Mind',
#   'authors': 'Kay Redfield Jamison',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Mary Queen of Scotland & The Isles',
#   'authors': 'Margaret George',
#   'categories': 'Fiction'},
#  {'title': 'Beauty',
#   'authors': 'Robin McKinley',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Masters of Death',
#   'authors': 'Richard Rhodes',
#   'categories': 'History'},
#  {'title': 'Smoke and Mirrors',
#   'authors': 'Neil Gaiman',
#   'categories': 'Fiction'},
#  {'title': 'The Terror', 'authors': 'Dan Simmons', 'categories': 'Fiction'},
#  {'title': 'Live Like a Jesus Freak',
#   'authors': 'DC Talk',
#   'categories': 'Religion'},
#  {'title': 'Healing Emotions',
#   'authors': 'Daniel Goleman',
#   'categories': 'Health & Fitness'},
#  {'title': 'The Namesake',
#   'authors': 'Jhumpa Lahiri;Mira Nair',
#   'categories': 'Performing Arts'},
#  {'title': 'Get Out of Your Mind & Into Your Life',
#   'authors': 'Steven C. Hayes;Spencer Xavier Smith',
#   'categories': 'Self-Help'},
#  {'title': 'Chickenhawk - Back in the World',
#   'authors': 'Robert Mason',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Murder at the Vicarage',
#   'authors': 'Agatha Christie',
#   'categories': 'Fiction'},
#  {'title': 'Duel', 'authors': 'Richard Matheson', 'categories': 'Fiction'},
#  {'title': 'Black Boy',
#   'authors': 'Richard Wright',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'My Little House Crafts Book',
#   'authors': 'Carolyn Strom Collins',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Looking Awry',
#   'authors': 'Slavoj Žižek',
#   'categories': 'Performing Arts'},
#  {'title': 'The Job',
#   'authors': 'William S. Burroughs',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Tsunamis and Other Natural Disasters',
#   'authors': 'Mary Pope Osborne;Natalie Pope Boyce',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Warlock', 'authors': 'Wilbur Smith', 'categories': 'Fiction'},
#  {'title': 'When Food is Love',
#   'authors': 'Geneen Roth',
#   'categories': 'Family & Relationships'},
#  {'title': 'Testaments Betrayed',
#   'authors': 'Milan Kundera',
#   'categories': 'Literary Collections'},
#  {'title': 'Foundations of Clinical Research',
#   'authors': 'Leslie Gross Portney;Mary P. Watkins',
#   'categories': 'Medical'},
#  {'title': 'Shadow of a Dark Queen',
#   'authors': 'Raymond E. Feist',
#   'categories': 'Fiction'},
#  {'title': 'The Rise of Christianity',
#   'authors': 'Rodney Stark',
#   'categories': 'Religion'},
#  {'title': 'Animal, Vegetable, Miracle',
#   'authors': 'Barbara Kingsolver;Camille Kingsolver;Steven L. Hopp',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Mother God',
#   'authors': 'Sylvia Browne',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'The Metamorphosis, in the Penal Colony and Other Stories',
#   'authors': 'Franz Kafka',
#   'categories': 'Fiction'},
#  {'title': 'Grand Theft Auto',
#   'authors': 'Tim Bogenn;Rick Barba',
#   'categories': 'Games & Activities'},
#  {'title': 'The Coal Tattoo',
#   'authors': 'Silas House',
#   'categories': 'Fiction'},
#  {'title': 'The War of the World',
#   'authors': 'Niall Ferguson',
#   'categories': 'History'},
#  {'title': 'Allusions in Ulysses',
#   'authors': 'Weldon Thornton',
#   'categories': 'Literary Criticism'},
#  {'title': 'Old Town in the Green Groves',
#   'authors': 'Cynthia Rylant;Jim LaMarche',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Christian Theology',
#   'authors': 'Alister E. McGrath',
#   'categories': 'Religion'},
#  {'title': 'Never Go Home Again',
#   'authors': 'Shannon Holmes',
#   'categories': 'Fiction'},
#  {'title': "It Doesn't Take a Hero",
#   'authors': 'H. Norman Schwarzkopf;Peter Petre',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Bad Astronomy',
#   'authors': 'Philip C. Plait',
#   'categories': 'Science'},
#  {'title': 'Realms of Dragons',
#   'authors': 'Margaret Weis;Denise Little;Tracy Hickman',
#   'categories': 'Fiction'},
#  {'title': 'The Sword of Welleran',
#   'authors': 'Lord Dunsany',
#   'categories': 'Fiction'},
#  {'title': 'Dirty Italian',
#   'authors': 'Gabrielle Euvino',
#   'categories': 'Foreign Language Study'},
#  {'title': 'Lawrence Durrell',
#   'authors': 'Ian S. MacNiven',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Science of Harry Potter',
#   'authors': 'Roger Highfield',
#   'categories': 'Magic'},
#  {'title': 'Doubling the Point',
#   'authors': 'Professor of General Literature J M Coetzee;J. M. Coetzee',
#   'categories': 'Literary Criticism'},
#  {'title': 'Darkness Visible',
#   'authors': 'William Styron',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Twentieth Wife',
#   'authors': 'Indu Sundaresan',
#   'categories': 'Fiction'},
#  {'title': 'Programming Ruby',
#   'authors': 'David Thomas',
#   'categories': 'Computers'},
#  {'title': 'Silos, Politics and Turf Wars',
#   'authors': 'Patrick M. Lencioni',
#   'categories': 'Business & Economics'},
#  {'title': "Roald Dahl's James and the giant peach",
#   'authors': 'Roald Dahl',
#   'categories': 'Drama'},
#  {'title': 'Sexus', 'authors': 'Henry Miller', 'categories': 'Fiction'},
#  {'title': 'The Annotated Christmas Carol',
#   'authors': 'Charles Dickens',
#   'categories': 'Fiction'},
#  {'title': 'Muhammad',
#   'authors': 'Karen Armstrong',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Collected Prose',
#   'authors': 'Paul Auster',
#   'categories': 'Literary Collections'},
#  {'title': 'The History of Sexuality',
#   'authors': 'Michel Foucault',
#   'categories': 'Sex customs'},
#  {'title': 'Comfort Me With Apples',
#   'authors': 'Ruth Reichl',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'When the Elephants Dance',
#   'authors': 'Tess Uriza Holthe',
#   'categories': 'Fiction'},
#  {'title': 'Marilyn Monroe',
#   'authors': 'Donald Spoto',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'A Scandalous Life',
#   'authors': 'Mary S. Lovell',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'A Crown of Swords',
#   'authors': 'Robert Jordan',
#   'categories': 'Fiction'},
#  {'title': 'Junie B., First Grader',
#   'authors': 'Barbara Park',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Armageddon',
#   'authors': 'Tim F. LaHaye;Jerry B. Jenkins',
#   'categories': 'Fiction'},
#  {'title': 'The Killer Department',
#   'authors': 'Robert Cullen',
#   'categories': 'Insane, Criminal and dangerous'},
#  {'title': 'Euripides I',
#   'authors': 'Euripides',
#   'categories': 'Greek drama (Tragedy)'},
#  {'title': "Spider's House",
#   'authors': 'Paul Bowles',
#   'categories': 'Fiction'},
#  {'title': 'George Eliot',
#   'authors': 'Kathryn Hughes',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Working Poor',
#   'authors': 'David K. Shipler',
#   'categories': 'Social Science'},
#  {'title': "Plato's Symposium",
#   'authors': 'Plato;Seth Benardete',
#   'categories': 'Philosophy'},
#  {'title': 'Strange Pilgrims',
#   'authors': 'Gabriel García Márquez',
#   'categories': 'Fiction'},
#  {'title': 'In the Name of Love',
#   'authors': 'Ann Rule',
#   'categories': 'Literary Criticism'},
#  {'title': 'The Living and the Dead',
#   'authors': 'Paul Hendrickson',
#   'categories': 'History'},
#  {'title': 'Shout!',
#   'authors': 'Philip Norman',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Melville',
#   'authors': 'Andrew Delbanco',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Beatrix Potter',
#   'authors': 'Linda Lear',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'C.G. Jung and Hermann Hesse',
#   'authors': 'Miguel Serrano',
#   'categories': 'Psychology'},
#  {'title': "The Skeptic's Dictionary",
#   'authors': 'Robert Carroll',
#   'categories': 'Science'},
#  {'title': 'Genome', 'authors': 'Matt Ridley', 'categories': 'Science'},
#  {'title': 'Last of the Wilds',
#   'authors': 'Trudi Canavan',
#   'categories': 'Fiction'},
#  {'title': 'Moral Politics',
#   'authors': 'George Lakoff',
#   'categories': 'Language Arts & Disciplines'},
#  {'title': 'Face Off', 'authors': 'Harry Hamernik', 'categories': 'Art'},
#  {'title': 'Remembrance of Things Past, Part 2',
#   'authors': 'Stéphane Heuet;Marcel Proust;Stanislas Brézet',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'The Punisher',
#   'authors': 'Garth Ennis;Jeff Youngquist;John McCrea',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Hemingway',
#   'authors': 'Jeffrey Meyers',
#   'categories': 'Literary Collections'},
#  {'title': 'A False Mirror',
#   'authors': 'Charles Todd',
#   'categories': 'Fiction'},
#  {'title': 'A Thread of Grace',
#   'authors': 'Mary Doria Russell',
#   'categories': 'Fiction'},
#  {'title': 'The Seventy Wonders of the Ancient World',
#   'authors': 'Christopher Scarre',
#   'categories': 'Architecture'},
#  {'title': 'Effigies', 'authors': 'Mary Anna Evans', 'categories': 'Fiction'},
#  {'title': 'Democracy in America',
#   'authors': 'Alexis Tocqueville;Gerald Bevan;Isaac Kramnick',
#   'categories': 'History'},
#  {'title': 'Imperial Life in the Emerald City',
#   'authors': 'Rajiv Chandrasekaran',
#   'categories': 'History'},
#  {'title': 'Youth in Revolt',
#   'authors': 'C. D. Payne',
#   'categories': 'Fiction'},
#  {'title': 'Last Train to Paradise',
#   'authors': 'Les Standiford',
#   'categories': 'History'},
#  {'title': 'The Return of the Shadow',
#   'authors': 'John Ronald Reuel Tolkien;Christopher Tolkien',
#   'categories': 'Fiction'},
#  {'title': 'Demonic Males',
#   'authors': 'Richard W. Wrangham;Dale Peterson',
#   'categories': 'Nature'},
#  {'title': '1491', 'authors': 'Charles C. Mann', 'categories': 'History'},
#  {'title': 'D.H. Lawrence',
#   'authors': 'John Worthen',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Eight Men Out',
#   'authors': 'Eliot Asinof',
#   'categories': 'Sports & Recreation'},
#  {'title': 'Islam', 'authors': 'Karen Armstrong', 'categories': 'Religion'},
#  {'title': 'Problems of the Self',
#   'authors': 'Bernard Williams',
#   'categories': 'Philosophy'},
#  {'title': 'The Five Dysfunctions of a Team',
#   'authors': 'Patrick M. Lencioni',
#   'categories': 'Business & Economics'},
#  {'title': 'Unweaving the Rainbow',
#   'authors': 'Richard Dawkins',
#   'categories': 'Science'},
#  {'title': 'America',
#   'authors': 'Jon Stewart;Ben Karlin;David Javerbaum',
#   'categories': 'Democracy'},
#  {'title': 'The Wealthy Barber',
#   'authors': 'David Chilton',
#   'categories': 'Finance, Personal'},
#  {'title': 'Understanding the Lord of the Rings',
#   'authors': 'Neil D. Isaacs;Rose A. Zimbardo',
#   'categories': 'Literary Criticism'},
#  {'title': "The Daily Show with Jon Stewart Presents America (The Book) Teacher's Edition",
#   'authors': 'Jon Stewart;The Writers of The Daily Show',
#   'categories': 'Humor'},
#  {'title': 'The War of Art',
#   'authors': 'Steven Pressfield',
#   'categories': 'Self-Help'},
#  {'title': 'I, Robot',
#   'authors': 'Harlan Ellison;Isaac Asimov',
#   'categories': 'Fiction'},
#  {'title': 'Euripides',
#   'authors': 'Pantelis Michelakis',
#   'categories': 'Drama'},
#  {'title': "Exile's Return",
#   'authors': 'Raymond E. Feist',
#   'categories': 'Fiction'},
#  {'title': 'Blood Lines',
#   'authors': 'Richard Matheson;Mark Dawidziak',
#   'categories': 'Fiction'},
#  {'title': "The -Alchemist's Kitchen",
#   'authors': 'Guy Ogilvy',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'The Oresteia of Aeschylus',
#   'authors': 'Aeschylus;Ted Hughes',
#   'categories': 'Drama'},
#  {'title': 'The Pact', 'authors': 'Jodi Picoult', 'categories': 'Fiction'},
#  {'title': "It's Called a Breakup Because It's Broken",
#   'authors': 'Greg Behrendt;Amiira Ruotola-Behrendt',
#   'categories': 'Self-Help'},
#  {'title': 'The Oresteia Trilogy',
#   'authors': 'Aeschylus;E. D. A. Morshead',
#   'categories': 'Drama'},
#  {'title': 'Aeschylus, 1', 'authors': 'Aeschylus', 'categories': 'Drama'},
#  {'title': 'Everest',
#   'authors': 'Broughton Coburn;Tim Cahill;David Breashears',
#   'categories': 'Nature'},
#  {'title': "World's End",
#   'authors': 'T. Coraghessan Boyle',
#   'categories': 'Fiction'},
#  {'title': 'Wittgenstein on Rules and Private Language',
#   'authors': 'Saul A. Kripke',
#   'categories': 'Philosophy'},
#  {'title': 'Oresteia',
#   'authors': 'Esquilo;Aeschylus',
#   'categories': 'Erinyes (Greek mythology)'},
#  {'title': 'Fragile Things',
#   'authors': 'Neil Gaiman',
#   'categories': 'Fiction'},
#  {'title': 'Oryx and Crake',
#   'authors': 'Margaret Atwood',
#   'categories': 'Fiction'},
#  {'title': 'Maurice',
#   'authors': 'Edward Morgan Forster',
#   'categories': 'Fiction'},
#  {'title': 'Shock Wave',
#   'authors': 'Clive Cussler',
#   'categories': 'Adventure stories'},
#  {'title': 'Rhinoceros',
#   'authors': 'Eugène Ionesco',
#   'categories': 'French drama'},
#  {'title': 'Parliament of Whores',
#   'authors': "P. J. O'Rourke",
#   'categories': 'Humor'},
#  {'title': 'Shards of a Broken Crown',
#   'authors': 'Raymond E. Feist',
#   'categories': 'Fiction'},
#  {'title': 'Hamlet: The Texts of 1603 and 1623',
#   'authors': 'William Shakespeare',
#   'categories': 'Drama'},
#  {'title': 'Desecration',
#   'authors': 'Tim F. LaHaye;Jerry B. Jenkins',
#   'categories': 'Fiction'},
#  {'title': 'From Hinton to Hamlet',
#   'authors': 'Sarah K. Herz;Donald R. Gallo',
#   'categories': 'Literary Criticism'},
#  {'title': 'Otherland',
#   'authors': 'Tad Williams',
#   'categories': 'Otherland (Imaginary place)'},
#  {'title': 'The Truth about Columbus',
#   'authors': 'James W. Loewen',
#   'categories': 'Education'},
#  {'title': 'Small Wonder',
#   'authors': 'Barbara Kingsolver',
#   'categories': 'Literary Collections'},
#  {'title': 'The grass harp',
#   'authors': 'Truman Capote',
#   'categories': 'Fiction'},
#  {'title': 'The Survivor',
#   'authors': 'John F. Harris',
#   'categories': 'History'},
#  {'title': 'Savage Beauty',
#   'authors': 'Nancy Milford',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Crucial Conversations',
#   'authors': 'Kerry Patterson;Joseph Grenny;Ron McMillan;Al Switzler',
#   'categories': 'Business & Economics'},
#  {'title': 'Strategies of Containment',
#   'authors': 'John Lewis Gaddis',
#   'categories': 'History'},
#  {'title': 'Dreaming in Pictures',
#   'authors': 'Douglas Robert Nickel;Lewis Carroll;San Francisco Museum of Modern Art',
#   'categories': 'Photography'},
#  {'title': "The Devil's in the Details",
#   'authors': 'Mary Jane Maffini',
#   'categories': 'Fiction'},
#  ...]

# %%
embeddings = list(df['embedding'])
embeddings
# Out:
# [array([ 0.05363257, -0.01825933,  0.01940475, ...,  0.00565691,
#          0.02335757, -0.01013471]),
#  array([ 0.06094174, -0.01059736,  0.06788503, ...,  0.01770096,
#         -0.04340661,  0.01640739]),
#  array([ 0.03172249,  0.03664881, -0.02836364, ..., -0.02915981,
#          0.03239426, -0.02483063]),
#  array([-0.01150288, -0.00928603,  0.01074105, ...,  0.00862716,
#          0.00284312,  0.00987628]),
#  array([ 0.0040979 ,  0.00466197,  0.00653712, ..., -0.01951379,
#         -0.01369624,  0.00075235]),
#  array([ 0.02268183,  0.05379694,  0.04883891, ...,  0.01714459,
#         -0.04443692, -0.03391848]),
#  array([-0.03922549,  0.03654709, -0.03486229, ..., -0.04354547,
#          0.01220396, -0.00626398]),
#  array([ 0.03677513,  0.02311316, -0.02703355, ..., -0.01193278,
#          0.00632279,  0.00155265]),
#  array([ 0.0147869 ,  0.02000307, -0.03327636, ..., -0.00523945,
#         -0.01422803,  0.00696265]),
#  array([ 0.00920521,  0.05878863,  0.01218149, ..., -0.00845405,
#          0.02080562, -0.03432644]),
#  array([-0.01838102,  0.01208842, -0.01311304, ..., -0.03473351,
#          0.00447106, -0.00373623]),
#  array([ 0.02644437,  0.04294284, -0.0323534 , ..., -0.00093288,
#          0.00496563, -0.00684146]),
#  array([-0.02330402,  0.01050354, -0.00335883, ...,  0.04069835,
#          0.00088371,  0.00667148]),
#  array([ 0.01455006, -0.02133125, -0.01471868, ...,  0.02801608,
#         -0.00094476, -0.03521885]),
#  array([ 0.00848459,  0.01713056, -0.01472235, ...,  0.00334542,
#         -0.01963807,  0.01261827]),
#  array([0.08395118, 0.06529029, 0.10174518, ..., 0.00358161, 0.01231892,
#         0.00886848]),
#  array([ 0.00255136, -0.01015371,  0.0283338 , ...,  0.00719269,
#          0.00555982,  0.00976849]),
#  array([ 0.02822188, -0.01779361,  0.00104208, ..., -0.04064046,
#         -0.00465995, -0.0006689 ]),
#  array([ 0.03998742,  0.05803483, -0.00168247, ...,  0.00846131,
#         -0.00841707,  0.01861614]),
#  array([-0.02626223, -0.02481702, -0.03732714, ..., -0.02077494,
#          0.02202821,  0.01542313]),
#  array([-0.02639066,  0.04683184, -0.00446789, ...,  0.04456317,
#          0.00622727, -0.0026926 ]),
#  array([ 0.01443431,  0.05186903, -0.01142561, ...,  0.0273767 ,
#          0.03177786, -0.01849979]),
#  array([ 0.00688392,  0.01927497, -0.01581334, ...,  0.03448515,
#         -0.00147922,  0.00408118]),
#  array([ 0.03162722,  0.04813962, -0.01315428, ..., -0.02976375,
#         0.01870692]),
#  array([ 0.01984687,  0.01219396,  0.0180489 , ...,  0.01204412,
#          0.0234774 , -0.05403144]),
#  array([ 0.04957639,  0.07514143,  0.02206926, ..., -0.03149725,
#          0.08912452, -0.06516024]),
#  array([ 0.01853943, -0.00025774,  0.0018246 , ..., -0.01898775,
#          0.00521833,  0.00274432]),
#  array([ 0.01842792,  0.02751628, -0.03009665, ...,  0.02004921,
#          0.0196496 , -0.05142462]),
#  array([-0.00890578,  0.031547  ,  0.01729487, ..., -0.00571951,
#          0.0290927 , -0.04222532]),
#  array([ 0.08870374,  0.03644685,  0.01164206, ...,  0.00559939,
#         -0.01335974, -0.03785054]),
#  array([ 0.02768945,  0.00205934,  0.01689652, ..., -0.00767291,
#          0.00090794, -0.02158586]),
#  array([ 0.01986715,  0.03685466, -0.00429225, ...,  0.04050867,
#         -0.02412613, -0.01269223]),
#  array([ 0.04526007,  0.01806288, -0.05123989, ..., -0.01416777,
#          0.02275347, -0.02364496]),
#  array([ 0.04255794, -0.03491081, -0.00260723, ..., -0.01500611,
#         -0.00428904, -0.02285273]),
#  array([ 0.00847826,  0.02669285, -0.0136418 , ...,  0.02295147,
#          0.02555512,  0.00798597]),
#  array([-0.03132511,  0.01660231,  0.0006442 , ..., -0.00237348,
#          0.0274938 , -0.00908428]),
#  array([ 0.03480875,  0.03262498,  0.05798827, ...,  0.02540276,
#         -0.00162138, -0.03067801]),
#  array([ 0.00414348, -0.00871832,  0.01987899, ...,  0.02928384,
#          0.03662303, -0.00923474]),
#  array([-0.00986339,  0.04604002,  0.00533656, ...,  0.04110561,
#          0.0018178 ,  0.00033523]),
#  array([ 0.03877162,  0.00575108, -0.02080338, ..., -0.02402398,
#          0.04600866, -0.01364095]),
#  array([ 0.03394917,  0.03256875,  0.0425593 , ..., -0.01799236,
#          0.00983847,  0.02737459]),
#  array([ 0.00037322,  0.04638519,  0.07330877, ..., -0.02096157,
#          0.00231453, -0.04499868]),
#  array([ 0.01004164,  0.01178431,  0.01089311, ..., -0.01975405,
#          0.00697068, -0.00702177]),
#  array([-0.00349938, -0.03063886,  0.05709872, ...,  0.00779297,
#         -0.00815011, -0.01200395]),
#  array([-0.01352553, -0.01733538,  0.00464072, ...,  0.01432456,
#          0.03029349,  0.0036014 ]),
#  array([ 0.02087885, -0.02243366,  0.02073513, ...,  0.01928485,
#          0.03655759, -0.02688903]),
#  array([ 0.02662146, -0.04159725, -0.02465455, ..., -0.01433314,
#          0.00274589,  0.01571582]),
#  array([ 0.05635991,  0.06723479,  0.01141638, ...,  0.00919402,
#          0.02933061, -0.01815114]),
#  array([ 0.00195154,  0.03784237,  0.02110907, ...,  0.00921074,
#          0.04178597, -0.02479607]),
#  array([0.01624086, 0.02619493, 0.05364721, ..., 0.01075738, 0.00085425,
#         0.00170704]),
#  array([-0.02426551,  0.02659831,  0.00137829, ...,  0.02039567,
#          0.00106557, -0.03396735]),
#  array([ 0.041121  ,  0.02039517,  0.05144259, ...,  0.01167378,
#          0.00507222, -0.01380541]),
#         -0.01372614, -0.04948404]),
#  array([-0.00456086, -0.00478127, -0.04993158, ..., -0.00115775,
#          0.02482553,  0.020718  ]),
#  array([ 0.0308962 ,  0.01305802,  0.0060335 , ...,  0.01587948,
#          0.00817875, -0.00751419]),
#  array([ 0.01419986,  0.00290144, -0.00232792, ..., -0.00265586,
#          0.01337634, -0.05218774]),
#  array([ 0.08793139,  0.0266707 ,  0.02912841, ...,  0.02507774,
#         -0.01961617, -0.0172381 ]),
#  array([ 0.00945695,  0.03586769,  0.02680531, ..., -0.03115831,
#          0.01937212, -0.04019524]),
#  array([ 0.03939661, -0.02050116,  0.01257435, ...,  0.00138733,
#         -0.02546531, -0.01760635]),
#  array([ 0.02413582,  0.04582979, -0.00335434, ...,  0.01636044,
#         -0.00514718, -0.01628333]),
#  array([-0.00393756,  0.02876989,  0.01333633, ...,  0.01663699,
#          0.03752472, -0.02746089]),
#  array([-0.01807341,  0.03630747, -0.01534232, ...,  0.01428201,
#          0.02705389, -0.00944637]),
#  array([-0.01847016,  0.01119713, -0.00085401, ..., -0.01799722,
#          0.00116237, -0.00081965]),
#  array([ 0.05448497,  0.06114938, -0.01638901, ...,  0.01716426,
#          0.00926897, -0.01310441]),
#  array([ 0.00316007,  0.0248411 ,  0.03062348, ...,  0.01043719,
#         -0.02003016, -0.02312952]),
#  array([ 0.04554239, -0.00081278, -0.00122001, ...,  0.01943948,
#          0.03715936, -0.00780535]),
#  array([0.06037291, 0.02626173, 0.00323426, ..., 0.00012463, 0.0120225 ,
#         0.00393381]),
#  array([ 0.00983291, -0.01105654,  0.00684792, ..., -0.03132047,
#         -0.00361327, -0.00617301]),
#  array([ 0.00920542,  0.01950224, -0.02190592, ...,  0.01663083,
#          0.00395632,  0.0046222 ]),
#  array([ 0.02366676,  0.05286004,  0.00630687, ..., -0.03466861,
#          0.00024446, -0.04497964]),
#  array([-0.02830723,  0.0051334 ,  0.05318794, ..., -0.0220551 ,
#          0.01430704,  0.00742202]),
#  array([ 0.02190414,  0.03613401, -0.02130005, ..., -0.00017235,
#         -0.00337288, -0.00236605]),
#  array([ 0.00348296,  0.03197473, -0.00592809, ..., -0.00454431,
#         -0.00594824, -0.01991032]),
#  array([-0.00528867, -0.01112673,  0.03658598, ..., -0.00303072,
#         -0.01270246, -0.03624789]),
#  array([-0.00568878,  0.00799974, -0.02308875, ..., -0.01962752,
#         -0.00458717, -0.0061336 ]),
#  array([ 0.0072392 ,  0.01615091, -0.05856265, ..., -0.01424126,
#         -0.00756372, -0.02631075]),
#  array([ 0.00011146, -0.01928588, -0.04331942, ...,  0.04263443,
#         -0.03141484, -0.00285214]),
#  array([-0.02442758, -0.02142368, -0.0515253 , ..., -0.00099348,
#          0.03381478, -0.01335069]),
#  array([ 0.02164526,  0.01109479,  0.02142522, ..., -0.00907387,
#         -0.01061417,  0.01154645]),
#  array([ 0.02379715,  0.02464407,  0.02252082, ..., -0.03265996,
#          0.00605664, -0.01250096]),
#  array([ 0.03840091, -0.02062013, -0.03023199, ..., -0.02247035,
#          0.03160512, -0.00960023]),
#  array([ 0.02704304,  0.02478391, -0.00741967, ..., -0.00837758,
#          0.01777398, -0.02489465]),
#  array([-0.03249049, -0.01276107,  0.01297482, ...,  0.00873716,
#         -0.03539753, -0.00106609]),
#  array([ 0.04141705,  0.03500269,  0.0009114 , ...,  0.01425813,
#          0.02798774, -0.01378967]),
#  array([-0.00370393,  0.02556588, -0.0272869 , ..., -0.00834321,
#         -0.03087859, -0.01456631]),
#  array([ 0.00449239,  0.02636557, -0.00549389, ..., -0.01828952,
#          0.03511997, -0.02599441]),
#  array([-0.00302484,  0.02024251,  0.02569818, ...,  0.01943512,
#         -0.00068448, -0.00952148]),
#  array([ 0.02049193,  0.03615087, -0.09379893, ...,  0.01712816,
#          0.01702184, -0.02625287]),
#  array([ 0.02946828,  0.08670379,  0.00657908, ...,  0.04457766,
#          0.00390868, -0.01842393]),
#  array([ 0.01190327,  0.03932741, -0.02539993, ...,  0.00899974,
#         -0.02443209,  0.00787256]),
#  array([-0.00670843,  0.01825478, -0.0213723 , ..., -0.03048237,
#         -0.00223999,  0.00734925]),
#  array([-0.01624729, -0.04730196, -0.03274402, ..., -0.03136079,
#          0.00232286, -0.00370751]),
#  array([ 0.02053552,  0.02831705,  0.00726615, ...,  0.02261966,
#         -0.00354246, -0.04643996]),
#  array([ 0.02996259,  0.02112889, -0.03829784, ..., -0.01517514,
#          0.02385653, -0.01489822]),
#  array([-0.05810611,  0.02251322, -0.02869134, ..., -0.01137236,
#         -0.00051047, -0.00100105]),
#  array([-0.00923077,  0.00265506, -0.01826823, ..., -0.01310915,
#          0.04492149,  0.00997987]),
#  array([ 0.00093313,  0.02633632, -0.02161197, ..., -0.00822194,
#          0.0005412 ,  0.04165785]),
#  array([ 0.03558775, -0.01843983,  0.01323186, ...,  0.0239203 ,
#          0.00899787, -0.00300013]),
#  array([ 0.0336806 ,  0.02734441, -0.03912539, ...,  0.01514182,
#          0.01028126, -0.02055047]),
#  array([-0.00303955, -0.05178142,  0.03069868, ...,  0.02233792,
#         -0.0143069 , -0.04493112]),
#  array([0.06956622, 0.03376719, 0.06303531, ..., 0.02704278, 0.00113913,
#         0.00917955]),
#  array([ 0.01911343,  0.00373207, -0.00544329, ..., -0.01498044,
#          0.03488918, -0.01984355]),
#  array([-0.02060929,  0.02215404, -0.00647415, ..., -0.01512101,
#          0.00233911, -0.00334383]),
#  array([ 0.021436  ,  0.01152691, -0.01356107, ..., -0.01055146,
#         -0.00077917, -0.00529357]),
#  array([-0.01787878, -0.03030671,  0.00866003, ..., -0.02600054,
#         -0.02192604, -0.00459575]),
#  array([0.06806982, 0.02251839, 0.00934359, ..., 0.04199469, 0.00530366,
#         0.00167401]),
#  array([ 0.01216349,  0.00589205,  0.03338637, ...,  0.0090134 ,
#         -0.00187827,  0.00179061]),
#  array([ 0.00959393,  0.02302292, -0.06151106, ..., -0.04182352,
#          0.03103036, -0.02042457]),
#  array([ 0.0056995 , -0.00452925, -0.00247541, ...,  0.02554996,
#         -0.02687197, -0.01324713]),
#  array([ 0.03899345,  0.01100508, -0.00433685, ..., -0.02363097,
#          0.00609566,  0.01077018]),
#  array([ 0.0679421 ,  0.01296992,  0.02449362, ...,  0.02663219,
#         -0.008562  ,  0.00381751]),
#  array([ 0.05149462,  0.01254575, -0.00634501, ..., -0.00666308,
#          0.00505634, -0.03129551]),
#  array([ 0.00036937,  0.02358641,  0.00735668, ..., -0.04990095,
#          0.00633032, -0.02631454]),
#  array([ 0.03124787,  0.09021984,  0.01968645, ..., -0.00168088,
#         -0.01938067, -0.01214386]),
#  array([ 0.06433447,  0.02525297,  0.03165065, ..., -0.017236  ,
#          0.04275719, -0.01892482]),
#  array([-0.01676522, -0.00600317, -0.00835142, ...,  0.01200634,
#          0.04415839,  0.0174513 ]),
#  array([ 0.02138367, -0.00716401, -0.03525417, ..., -0.00195355,
#         -0.00717003,  0.01173333]),
#  array([-0.00600584,  0.0070152 , -0.01725087, ...,  0.03485694,
#         -0.01121839, -0.02607166]),
#  array([ 0.06502427, -0.00285422,  0.02354537, ...,  0.02559899,
#          0.00444526, -0.02710361]),
#  array([-0.01949601,  0.04956078,  0.01040574, ...,  0.05482268,
#         -0.01837167, -0.00571444]),
#  array([ 0.02337403,  0.08320346,  0.016153  , ...,  0.01685355,
#         -0.00557407, -0.02057184]),
#  array([ 0.03530096,  0.04670588,  0.02745081, ...,  0.03441226,
#         -0.00043123,  0.01483628]),
#  array([ 0.02897125,  0.03433101, -0.03127237, ..., -0.0111197 ,
#         -0.01274907,  0.00279779]),
#  array([ 0.02324642,  0.0238905 ,  0.01727081, ...,  0.01818922,
#         -0.00657794, -0.05190786]),
#  array([ 0.01726139,  0.03844881,  0.01243893, ..., -0.02402723,
#         -0.00373626, -0.00649429]),
#  array([ 0.06193645,  0.01870948, -0.00581385, ..., -0.00924957,
#          0.03108509, -0.00450792]),
#  array([0.04991271, 0.03451411, 0.03095881, ..., 0.0074973 , 0.00020633,
#         0.00318015]),
#  array([ 0.03421505,  0.02955314,  0.03349356, ..., -0.00745766,
#         -0.0206872 , -0.01645541]),
#  array([-0.00761349, -0.02595299, -0.05337999, ..., -0.02550553,
#          0.05164278,  0.00053918]),
#  array([ 0.03993276,  0.00608987,  0.0141853 , ..., -0.02252585,
#          0.02671522, -0.01519126]),
#  array([-0.00769102,  0.00531586, -0.03946999, ...,  0.01002034,
#          0.01203786, -0.00661501]),
#  array([ 0.03464624, -0.02539341,  0.0019307 , ...,  0.04352563,
#         -0.00491167, -0.02054916]),
#  array([ 0.05351024,  0.02099722,  0.04113137, ..., -0.00303923,
#          0.01500506, -0.00584729]),
#  array([ 0.00779189, -0.03901517, -0.01302156, ..., -0.00141882,
#         -0.0059383 , -0.03319755]),
#  array([-0.02038131,  0.04786503,  0.02256126, ...,  0.01851781,
#          0.00015749, -0.0245654 ]),
#  array([ 0.05076588,  0.02087091, -0.04243085, ..., -0.00206848,
#          0.02491618, -0.01235807]),
#  array([-0.0105765 , -0.02789679, -0.0355847 , ..., -0.05062334,
#          0.00910411,  0.001105  ]),
#         -0.02438321, -0.01931298]),
#  array([ 0.04870643,  0.03221055, -0.01330338, ...,  0.00144132,
#         -0.03512512,  0.00020939]),
#  array([-0.03973161, -0.0200914 , -0.000632  , ..., -0.00940209,
#         -0.01741078,  0.01024476]),
#  array([ 0.02946828,  0.08670379,  0.00657908, ...,  0.04457766,
#          0.00390868, -0.01842393]),
#  array([-0.04894285,  0.06016277, -0.06681161, ..., -0.02271687,
#          0.0163797 , -0.03061237]),
#  array([ 0.03578582, -0.01216383, -0.03092985, ..., -0.00822284,
#          0.01814408, -0.00837235]),
#  array([-0.03625992,  0.02488697,  0.00527496, ...,  0.01885516,
#         -0.03782543, -0.0277187 ]),
#  array([ 0.00531418,  0.03860207, -0.00340927, ...,  0.01031996,
#          0.01311056, -0.0171197 ]),
#  array([ 3.16981971e-02, -4.04049968e-03,  1.90115843e-05, ...,
#         -1.99440159e-02,  3.10451873e-02, -5.88389300e-03]),
#  array([ 0.0143083 ,  0.02009404, -0.00037905, ..., -0.02173853,
#         -0.01256778, -0.02292689]),
#  array([ 0.00110378,  0.02813016, -0.00953386, ..., -0.00836587,
#         -0.01559191, -0.03337906]),
#  array([ 0.00110374, -0.01882958,  0.01744598, ...,  0.0004253 ,
#          0.04178482, -0.02471618]),
#  array([ 0.0219317 ,  0.05663376,  0.01241072, ...,  0.01815864,
#          0.01669485, -0.03129495]),
#  array([-0.04539805,  0.03666124,  0.01900909, ..., -0.03673266,
#          0.00560929, -0.00441899]),
#  array([ 0.00899629,  0.00441272,  0.03863334, ...,  0.00151495,
#         -0.0243247 , -0.00469302]),
#  array([ 0.04132191,  0.00484225, -0.00343015, ...,  0.00160029,
#          0.01439327,  0.01149966]),
#  array([ 0.02075889,  0.03612586, -0.01046706, ...,  0.00473815,
#          0.01893912, -0.01508389]),
#  array([ 0.01943261, -0.01541897, -0.0030426 , ..., -0.02937843,
#          0.05254219, -0.03046129]),
#  array([ 0.04052659, -0.01720489,  0.00130121, ..., -0.02255432,
#          0.01265622, -0.01995189]),
#  array([ 0.04478176,  0.06753061, -0.03004696, ...,  0.02528934,
#          0.01845313, -0.03348816]),
#  array([-0.00850177, -0.00640737, -0.02697564, ..., -0.00689421,
#          0.03330133,  0.01624551]),
#  array([0.05358486, 0.03778019, 0.02239212, ..., 0.0010952 , 0.00526605,
#         0.00242798]),
#  array([-0.02156098,  0.01879168,  0.03602562, ...,  0.00954419,
#          0.01859387, -0.02440445]),
#  array([ 0.03698953, -0.03643547, -0.02480005, ..., -0.02003508,
#          0.00982915,  0.00462923]),
#  array([ 0.07110881,  0.05425564,  0.01286744, ..., -0.01475687,
#          0.01979076, -0.02521081]),
#  array([ 0.00285929,  0.04191111, -0.01996484, ..., -0.03717072,
#          0.02874335,  0.01923748]),
#  array([-0.01485223,  0.03687213,  0.03266801, ...,  0.04615333,
#          0.02058407, -0.01906783]),
#  array([ 0.02786811,  0.02271395, -0.01070585, ..., -0.00977372,
#         -0.0023766 , -0.03451643]),
#  array([ 0.02438791,  0.07568044, -0.02981738, ..., -0.028361  ,
#         -0.01286465, -0.00213506]),
#  array([0.01445434, 0.01243002, 0.04294867, ..., 0.02736972, 0.00715022,
#         0.02063383]),
# ...
#  array([ 0.03047325, -0.00331409, -0.02277926, ...,  0.00864628,
#          0.0133825 , -0.02282971]),
#  array([ 0.02530743, -0.02356299,  0.02288604, ...,  0.03277989,
#          0.021428  , -0.00627804]),
#  array([-0.00864325,  0.01793903,  0.03635265, ...,  0.00471018,
#         -0.00399238, -0.04290182]),
#  array([-0.02232896, -0.00239671, -0.02751527, ...,  0.01021547,
#         -0.02903852, -0.03522825]),
#  array([ 0.04057911,  0.02970876,  0.02772994, ...,  0.01168826,
#         -0.06749113, -0.00930707]),
#  array([ 0.03618935,  0.01490349, -0.02928644, ...,  0.0053441 ,
#          0.0166462 , -0.02539365]),
#  array([ 0.02229385,  0.00699614,  0.02839012, ..., -0.00781996,
#         -0.01146378,  0.01527236]),
#  array([ 0.03444188,  0.04222506, -0.01238293, ...,  0.00089017,
#          0.00403719, -0.03195339]),
#  array([ 0.02591887, -0.04413581,  0.05364031, ...,  0.0014057 ,
#         -0.00573547,  0.02277801]),
#  array([ 0.04916434, -0.00117334,  0.04416132, ...,  0.0284066 ,
#          0.01806381,  0.0280458 ]),
#  array([ 0.01913633,  0.0018425 , -0.01905084, ...,  0.00086935,
#         -0.0103131 , -0.04667457]),
#  array([ 0.00543287,  0.02722798,  0.03496379, ...,  0.01073851,
#          0.00533745, -0.00666068]),
#  array([ 0.05308659, -0.01105242, -0.02964803, ...,  0.03478614,
#          0.04582763, -0.01968883]),
#  array([ 0.01525604,  0.00561555,  0.00576377, ...,  0.01468594,
#         -0.01962306, -0.04273516]),
#  array([-0.00654764, -0.0165552 ,  0.07686242, ..., -0.00175149,
#         -0.0363084 ,  0.01714793]),
#  array([ 0.02747126,  0.02281452, -0.01093807, ...,  0.02883193,
#         -0.00599394,  0.00766544]),
#  array([ 0.02140772,  0.06526237, -0.00226461, ..., -0.00271782,
#          0.01926002, -0.03022945]),
#  array([ 0.01099574,  0.03419587,  0.03304029, ..., -0.00329872,
#          0.01673239,  0.00250721]),
#  array([ 0.02043761,  0.02007759, -0.04085123, ..., -0.03230655,
#          0.01803743,  0.00903071]),
#  array([ 0.02367966,  0.03300139,  0.01931223, ..., -0.03865175,
#          0.01766079, -0.02679145]),
#  array([-0.00818453,  0.03386944,  0.01530842, ..., -0.00044893,
#         -0.03825337, -0.05387998]),
#  array([-0.00651671,  0.02402795,  0.02751376, ..., -0.00483409,
#          0.00419283, -0.00867615]),
#  array([-0.01224633,  0.0140652 ,  0.04338183, ...,  0.00875545,
#         -0.02336292, -0.01099797]),
#  array([-0.00110269,  0.00031288,  0.01843307, ..., -0.00980903,
#          0.02951486,  0.00894223]),
#  array([-0.00095269,  0.00824883,  0.03204183, ...,  0.02955777,
#          0.00937794,  0.00314271]),
#  array([-0.02320264,  0.00502428,  0.00277555, ...,  0.00280051,
#         -0.00131153, -0.01874401]),
#  array([ 0.01352289,  0.05310523, -0.00203265, ..., -0.01583294,
#         -0.00543771, -0.03516989]),
#  array([-0.0147552 ,  0.06793368,  0.00516975, ...,  0.00856644,
#          0.02380396, -0.01569268]),
#  array([-0.01460272,  0.0407449 , -0.01925295, ...,  0.02471513,
#          0.02204555,  0.02758154]),
#  array([ 0.00615594, -0.00442353, -0.0099964 , ..., -0.00317609,
#         -0.00598775, -0.00446839]),
#  array([ 0.05008652,  0.06153908, -0.05220008, ...,  0.00938815,
#          0.02377758, -0.04539245]),
#  array([-0.00533867,  0.01779556,  0.04626846, ..., -0.00295936,
#         -0.00169931,  0.0264005 ]),
#  array([ 0.01386022,  0.04695908, -0.00402554, ...,  0.02511405,
#         -0.00296531, -0.03308782]),
#  array([ 0.06092443,  0.02185229,  0.02977152, ..., -0.01063439,
#         -0.00724043,  0.0141117 ]),
#  array([-0.04418341,  0.04452497,  0.03842566, ...,  0.03164323,
#          0.0186029 , -0.02991102]),
#  array([ 0.03870632,  0.02503946, -0.00065143, ...,  0.01603512,
#         -0.01152062, -0.03147818]),
#  array([ 0.0320519 , -0.01738816,  0.02358104, ..., -0.03685969,
#         -0.03926358,  0.00084637]),
#  array([-0.00768385,  0.06912961, -0.07568716, ...,  0.01922213,
#          0.02027335, -0.01834613]),
#  array([0.00953564, 0.0111048 , 0.04047618, ..., 0.00482147, 0.0070612 ,
#         0.00103269]),
#  array([ 0.03229703,  0.03547763, -0.01911863, ...,  0.01999563,
#          0.0135409 ,  0.00569466]),
#  array([ 0.0074202 ,  0.02988889,  0.0156468 , ...,  0.01459327,
#          0.00693896, -0.00171848]),
#  array([-0.02374818,  0.00303507,  0.00689762, ...,  0.04138571,
#         -0.00251572, -0.02014892]),
#  array([-0.03127085,  0.05705304, -0.01894546, ...,  0.02091945,
#          0.03490587, -0.04561836]),
#  array([ 0.01842479,  0.04042549,  0.04532017, ...,  0.02473969,
#         -0.02292638,  0.00333498]),
#  array([ 0.02163905,  0.05774018,  0.04022349, ...,  0.00093767,
#          0.00867049, -0.00856236]),
#  array([ 0.01322438,  0.01529069, -0.02493346, ...,  0.0016687 ,
#          0.00146911,  0.01544097]),
#  array([-0.00492506,  0.05983794, -0.02864799, ...,  0.03340147,
#         -0.00610708, -0.03866335]),
#  array([ 0.06446962,  0.01680598,  0.04878404, ..., -0.02113586,
#          0.01332808, -0.00173895]),
#  array([-0.00071295,  0.02754592, -0.00178508, ...,  0.02191791,
#          0.02808603, -0.02101051]),
#  array([-0.00077993,  0.0382363 ,  0.01424775, ...,  0.03586167,
#         -0.01668295,  0.00851715]),
#  array([ 0.02194789,  0.01191564, -0.01489141, ..., -0.00840624,
#          0.01096767, -0.02729674]),
#  array([ 0.02499356,  0.04544284,  0.00681051, ..., -0.00404429,
#          0.00502356, -0.01622451]),
#  array([-0.03959566,  0.00876125, -0.00502365, ..., -0.0317062 ,
#         -0.01156831, -0.02255543]),
#  array([-0.00466327,  0.05727422,  0.00494027, ..., -0.02695687,
#          0.02693252, -0.00873602]),
#  array([-0.01782305,  0.00803077,  0.04586508, ...,  0.03190424,
#          0.00024276,  0.0008746 ]),
#          0.02014667, -0.03363139]),
#  array([-0.00320519,  0.02035101, -0.02180379, ..., -0.02062946,
#         -0.00634986, -0.01499994]),
#  array([ 0.03166466, -0.02102222, -0.01011714, ...,  0.00895099,
#          0.00171771, -0.00417345]),
#  array([ 0.00787797,  0.04957933,  0.01698245, ...,  0.01214717,
#         -0.02003694, -0.02056764]),
#  array([ 0.02916671, -0.00602862, -0.04481306, ...,  0.01920559,
#          0.03867395, -0.01881145]),
#  array([ 0.06463597, -0.03569449,  0.0054475 , ...,  0.01420859,
#          0.02489387, -0.02803968]),
#  array([-0.01163638,  0.01000631, -0.02744867, ...,  0.00984758,
#          0.0127353 , -0.0258125 ]),
#  array([-0.00987138,  0.0577363 , -0.03354071, ...,  0.00718234,
#          0.0320603 , -0.02361729]),
#  array([ 0.04566297,  0.00290421, -0.03750476, ...,  0.00924405,
#         -0.0014284 , -0.00918085]),
#  array([ 0.02939945,  0.02687571,  0.00361128, ...,  0.00107439,
#          0.01463331, -0.02585735]),
#  array([ 0.06761587, -0.04663997,  0.02766983, ..., -0.01984011,
#          0.03549954,  0.03528205]),
#  array([ 0.00637406, -0.01655999, -0.00061237, ..., -0.01538447,
#          0.00779495, -0.01046555]),
#  array([ 0.01548735,  0.02602599, -0.06088995, ...,  0.01860991,
#         -0.00414715, -0.0358537 ]),
#  array([ 0.02700276,  0.01074562,  0.05193408, ...,  0.02441346,
#         -0.00293917,  0.01562215]),
#  array([ 0.01831319,  0.01019094,  0.00399814, ..., -0.00291075,
#          0.00986605, -0.00708791]),
#  array([ 0.03210586,  0.02383363, -0.02181952, ...,  0.01590907,
#          0.00765481, -0.00580855]),
#  array([ 0.01398773,  0.02552106, -0.02328112, ...,  0.02683167,
#         -0.03388511, -0.01797912]),
#  array([-0.01007693,  0.05915539, -0.01990557, ..., -0.00010095,
#          0.03000949, -0.04140878]),
#  array([ 0.02936815,  0.01742143,  0.02440273, ...,  0.02230197,
#         -0.04935717,  0.00479832]),
#  array([ 0.01735574, -0.00649989, -0.0074244 , ...,  0.00112727,
#          0.01634615,  0.00236656]),
#  array([-0.03072127,  0.02012818, -0.01383241, ..., -0.03354261,
#          0.00563615, -0.05835996]),
#  array([-0.04314779,  0.06537405,  0.04333091, ..., -0.0161375 ,
#         -0.01731634, -0.02072696]),
#  array([ 0.01578354,  0.01438348,  0.0645701 , ..., -0.03664078,
#          0.02327443, -0.03336202]),
#  array([ 0.0752314 ,  0.05189744, -0.02859405, ..., -0.0035819 ,
#          0.03730989, -0.01925129]),
#  array([ 0.01408791,  0.00786804,  0.02385919, ...,  0.00447687,
#         -0.00310013, -0.02864673]),
#  array([ 0.06251775,  0.05092632,  0.03893108, ..., -0.03092634,
#         -0.03045128, -0.02581945]),
#  array([-0.00149586,  0.02104479, -0.0098664 , ..., -0.00504585,
#          0.01325901,  0.01343129]),
#  array([-0.01612732,  0.02997871, -0.01528302, ...,  0.01622521,
#          0.00521262, -0.0002669 ]),
#  array([ 0.00972393,  0.04815779,  0.01575289, ..., -0.00095146,
#          0.03658021,  0.00062045]),
#  array([ 0.01481971,  0.06648184,  0.03499301, ...,  0.03406829,
#         -0.02545388, -0.00933228]),
#  array([ 0.03868339,  0.02639416, -0.00310275, ...,  0.01024656,
#          0.03824053,  0.01182423]),
#  array([ 0.01277069,  0.00168602, -0.00028095, ...,  0.02271571,
#          0.02626987, -0.03284838]),
#  array([-0.01613032, -0.00426863, -0.02714615, ..., -0.00231627,
#          0.00307853,  0.03559162]),
#  array([-0.02280253,  0.00496382,  0.05274055, ..., -0.01884699,
#         -0.0234424 , -0.03492123]),
#  array([ 0.05570178,  0.02584323,  0.01330606, ..., -0.00046454,
#          0.01678742, -0.00889029]),
#  array([-0.02697831,  0.01824248, -0.00100366, ...,  0.03054972,
#         -0.00607654, -0.01497938]),
#  array([-0.00277514, -0.0199534 , -0.00711994, ..., -0.01989062,
#          0.00937396,  0.00760967]),
#  array([ 0.03163771,  0.0082555 ,  0.00960206, ...,  0.01824768,
#         -0.02660386, -0.0226523 ]),
#  array([ 0.01620129,  0.0329661 , -0.03465667, ..., -0.03626271,
#         -0.0094531 ,  0.01254543]),
#  array([ 0.00848062,  0.01476836,  0.01566342, ..., -0.0016013 ,
#          0.0333407 ,  0.00361657]),
#  array([ 0.01714055,  0.01161692, -0.02946793, ...,  0.01225057,
#         -0.01294182, -0.05158807]),
#  array([-0.01846734, -0.00819701,  0.00428827, ...,  0.03043146,
#         -0.0213564 , -0.01076884]),
#  array([ 0.01722521,  0.02723645, -0.02407113, ...,  0.00466209,
#          0.03032815,  0.00195839]),
#  array([ 0.01203508,  0.02097869,  0.00074693, ...,  0.02509263,
#          0.00070332, -0.04118751]),
#  array([-0.02160158,  0.05502478,  0.0302108 , ...,  0.00269841,
#         -0.00523978, -0.05610986]),
#  array([ 0.0294089 ,  0.05625836, -0.01062535, ...,  0.00674313,
#          0.00417754, -0.02309644]),
#  array([ 0.01287484,  0.03253179,  0.02148825, ..., -0.01232476,
#         -0.01240831, -0.00081164]),
#  array([-0.00550974,  0.04421441, -0.00698242, ...,  0.03295611,
#          0.01513616, -0.04830834]),
#  array([ 0.02065059,  0.05134239, -0.01755474, ..., -0.00989048,
#          0.03589794, -0.02687707]),
#  array([ 0.02588861,  0.00748112,  0.03703646, ...,  0.02383376,
#         -0.03078579, -0.01642647]),
#  array([ 0.00577107,  0.01034635,  0.01236779, ...,  0.02671716,
#          0.01995246, -0.01827837]),
#  array([ 0.01800837,  0.02769148,  0.00191436, ...,  0.040491  ,
#          0.01826436, -0.04476492]),
#  array([ 0.03555614,  0.01699184,  0.02703675, ...,  0.00940536,
#          0.03961635, -0.00821429]),
#  array([-0.0089355 ,  0.04057128,  0.01669595, ..., -0.01904604,
#          0.00873535, -0.03264297]),
#  array([-0.00957559,  0.07425325, -0.00853551, ..., -0.0121419 ,
#          0.0377145 , -0.0076763 ]),
#  array([ 0.01158757, -0.00047606,  0.00053198, ...,  0.00914367,
#          0.03010979, -0.01980849]),
#  array([ 0.0368978 ,  0.07668258, -0.01570119, ..., -0.01275089,
#         -0.00405192, -0.02440016]),
#  array([0.00455093, 0.0489138 , 0.02385474, ..., 0.00824494, 0.05118347,
#         0.00299921]),
#  array([ 0.02089241,  0.03812446, -0.01926845, ..., -0.00344125,
#          0.01053642, -0.02138218]),
#  array([-0.01007698,  0.03917781,  0.02793447, ...,  0.00985241,
#          0.01432946, -0.00306077]),
#  array([ 0.01401644,  0.06625105, -0.02141012, ...,  0.01583858,
#         -0.00705494, -0.03464397]),
#  array([ 0.01396967,  0.06795501, -0.04784483, ..., -0.00345724,
#          0.01112328, -0.02752997]),
#  array([ 0.02268068,  0.02782126,  0.01165104, ...,  0.00453331,
#          0.01834509, -0.02616894]),
#  array([-0.00277082,  0.04059292,  0.00464088, ..., -0.00080179,
#          0.01623218, -0.0074491 ]),
#  array([ 0.0027838 ,  0.07137889,  0.04417207, ...,  0.0721165 ,
#         -0.00104082, -0.03327799]),
#  array([-0.02152301,  0.01059416,  0.0482208 , ..., -0.0010274 ,
#          0.008438  , -0.02426487]),
#  array([-0.01423287,  0.04033101, -0.00761989, ..., -0.00203254,
#         -0.00852476, -0.04041265]),
#  array([ 0.02187231,  0.02926462,  0.0261718 , ...,  0.02391076,
#          0.01367166, -0.0132382 ]),
#  array([ 0.03175002, -0.01569358,  0.06028617, ...,  0.01429399,
#          0.04196187, -0.02687737]),
#  array([ 0.02604496,  0.00327743,  0.03085518, ...,  0.01816916,
#         -0.02164598,  0.02416324]),
#  array([ 0.01846125,  0.0285349 ,  0.0104845 , ..., -0.02388224,
#         -0.0091666 , -0.01381926]),
#  array([ 0.03152667, -0.01441118,  0.00236331, ...,  0.01455351,
#          0.01388929, -0.04711209]),
#  array([-0.00097081,  0.00417742,  0.0027637 , ..., -0.01164317,
#         -0.02271105, -0.00155182]),
#  array([ 0.00974916,  0.05407408,  0.02140626, ..., -0.00417073,
#          0.00689305, -0.0452789 ]),
#  array([ 0.05586561, -0.04550598, -0.03865199, ..., -0.01468551,
#         -0.00442419,  0.00515454]),
#  array([ 0.03050765,  0.01150334,  0.01658329, ..., -0.00933422,
#         -0.00317671, -0.0207536 ]),
#  ...]

# %%
embeddings = np.array(embeddings)
project = atlas.map_data(
    embeddings = embeddings,
    data = data)
# Out:
# 2024-04-28 22:35:44.871 | INFO     | nomic.dataset:_create_project:914 - Creating dataset `oblivious-fourier`
# 2024-04-28 22:35:45.988 | INFO     | nomic.atlas:map_data:110 - Uploading data to Atlas.
# 1it [00:03,  3.37s/it]
# 2024-04-28 22:35:49.389 | INFO     | nomic.dataset:_add_data:1593 - Upload succeeded.
# 2024-04-28 22:35:49.393 | INFO     | nomic.atlas:map_data:125 - `atefataya/oblivious-fourier`: Data upload succeeded to dataset`
# 2024-04-28 22:35:50.356 | WARNING  | nomic.dataset:create_index:1160 - You did not specify the `topic_label_field` option in your topic_model, your dataset will not contain auto-labeled topics.
# 2024-04-28 22:35:53.056 | INFO     | nomic.dataset:create_index:1297 - Created map `oblivious-fourier` in dataset `atefataya/oblivious-fourier`: https://atlas.nomic.ai/data/atefataya/oblivious-fourier/map
